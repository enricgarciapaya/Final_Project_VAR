# %%
# Proyecto final Bueno
# Proyecto final Bueno
# !pip install pandas numpy matplotlib seaborn statsmodels scikit-learn scipy
# Out:
# Requirement already satisfied: pandas in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (3.8.3)
# Requirement already satisfied: seaborn in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (0.14.1)
# Requirement already satisfied: scikit-learn in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: scipy in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: six in c:\users\enric\anaconda3\envs\final_project\lib\site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)

# %%
#0 Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.stats.stattools import durbin_watson
from statsmodels.tsa.api import VAR
from statsmodels.tsa.api import VECM
from statsmodels.tsa.vector_ar.vecm import select_coint_rank
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.statespace.varmax import VARMAX
from sklearn import metrics
from sklearn.model_selection import ParameterGrid
import scipy

import warnings
warnings.filterwarnings('ignore')

# %%
#1. Import-transformation of the variable

# %%
UK = pd.read_csv("millenniumofdata_v3_headlines.csv", skiprows=[1])

# %%
display(UK)
# Out:
#      Description  Real GDP of England at market prices  \
# 0           2016                             1672084.0
# 1           2015                             1642802.0
# 2           2014                             1604169.0
# 3           2013                             1551553.0
# 4           2012                             1530435.0
# ..           ...                                   ...
# 803         1213                                   NaN
# 804         1212                                   NaN
# 805         1211                                   NaN
# 806         1210                                   NaN
# 807         1209                                   NaN
#
#      Real GDP of England at factor cost   \
# 0                              1413759.0
# 1                              1388074.0
# 2                              1352028.0
# 3                              1302596.0
# 4                              1282939.0
# ..                                   ...
# 803                                  NaN
# 804                                  NaN
# 805                                  NaN
# 806                                  NaN
# 807                                  NaN
#
#      Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0                                            1865410.0
# 1                                            1832318.0
# 2                                            1792976.0
# 3                                            1739563.0
# 4                                            1706942.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders  \
# 0                                            1648678.0
# 1                                            1618725.0
# 2                                            1580198.0
# 3                                            1527959.0
# 4                                            1505417.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Index of real UK GDP at factor cost - based on changing political boundaries,   \
# 0                                             872.4447
# 1                                             856.5943
# 2                                             836.2066
# 3                                             808.5629
# 4                                             796.6341
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Composite estimate of English and (geographically-consistent) UK real GDP at factor cost  \
# 0                                             107.9007
# 1                                             105.9403
# 2                                             103.4189
# 3                                             100.0000
# 4                                              98.5247
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      HP-filter of log of real composite estimate of English and UK real GDP at factor cost  \
# 0                                                 1.55
# 1                                                 1.09
# 2                                                 0.04
# 3                                                -2.01
# 4                                                -2.25
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real UK gross disposable national income at market prices, constant border estimate  \
# 0                                            1843502.0
# 1                                            1793997.0
# 2                                            1749880.0
# 3                                            1702359.0
# 4                                            1681556.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real consumption  ...  UK Public sector debt.1  UK Public sector debt.2  \
# 0           1223627.0  ...                     87.7                     87.7
# 1           1190789.0  ...                     86.0                     86.0
# 2           1163136.0  ...                     85.4                     85.4
# 3           1138546.0  ...                     83.6                     83.6
# 4           1121061.0  ...                     80.6                     80.6
# ..                ...  ...                      ...                      ...
# 803               NaN  ...                      NaN                      NaN
# 804               NaN  ...                      NaN                      NaN
# 805               NaN  ...                      NaN                      NaN
# 806               NaN  ...                      NaN                      NaN
# 807               NaN  ...                      NaN                      NaN
#
#      Central Government Gross Debt  Central Government Gross Debt.1  \
# 0                        1628685.0                        2070854.0
# 1                        1581986.0                        2005548.0
# 2                        1502068.0                        1736853.0
# 3                        1404319.0                        1731089.0
# 4                        1329598.0                        1569916.0
# ..                             ...                              ...
# 803                            NaN                              NaN
# 804                            NaN                              NaN
# 805                            NaN                              NaN
# 806                            NaN                              NaN
# 807                            NaN                              NaN
#
#      Trade deficit  Trade deficit.1  Current account   Current account .1  \
# 0         -37026.0            -1.91          -84504.0                -4.4
# 1         -29788.0            -1.59          -80233.0                -4.3
# 2         -36223.0            -1.99          -84998.0                -4.7
# 3         -39238.0            -2.26          -76442.0                -4.4
# 4         -37334.0            -2.23          -61433.0                -3.7
# ..             ...              ...               ...                 ...
# 803            NaN              NaN               NaN                 NaN
# 804            NaN              NaN               NaN                 NaN
# 805            NaN              NaN               NaN                 NaN
# 806            NaN              NaN               NaN                 NaN
# 807            NaN              NaN               NaN                 NaN
#
#      Current account deficit including estimated non-monetary bullion flows  \
# 0                                             -84504.0
# 1                                             -80233.0
# 2                                             -84998.0
# 3                                             -76442.0
# 4                                             -61433.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Current account deficit including estimated non-monetary bullion flows.1
# 0                                                 -4.4
# 1                                                 -4.3
# 2                                                 -4.7
# 3                                                 -4.4
# 4                                                 -3.7
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
# [808 rows x 77 columns]

# %%
df=UK.copy()

# %%
df.head()
# Out:
#    Description  Real GDP of England at market prices  \
# 0         2016                             1672084.0
# 1         2015                             1642802.0
# 2         2014                             1604169.0
# 3         2013                             1551553.0
# 4         2012                             1530435.0
#
#    Real GDP of England at factor cost   \
# 0                            1413759.0
# 1                            1388074.0
# 2                            1352028.0
# 3                            1302596.0
# 4                            1282939.0
#
#    Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0                                          1865410.0
# 1                                          1832318.0
# 2                                          1792976.0
# 3                                          1739563.0
# 4                                          1706942.0
#
#    Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders  \
# 0                                          1648678.0
# 1                                          1618725.0
# 2                                          1580198.0
# 3                                          1527959.0
# 4                                          1505417.0
#
#    Index of real UK GDP at factor cost - based on changing political boundaries,   \
# 0                                           872.4447
# 1                                           856.5943
# 2                                           836.2066
# 3                                           808.5629
# 4                                           796.6341
#
#    Composite estimate of English and (geographically-consistent) UK real GDP at factor cost  \
# 0                                           107.9007
# 1                                           105.9403
# 2                                           103.4189
# 3                                           100.0000
# 4                                            98.5247
#
#    HP-filter of log of real composite estimate of English and UK real GDP at factor cost  \
# 0                                               1.55
# 1                                               1.09
# 2                                               0.04
# 3                                              -2.01
# 4                                              -2.25
#
#    Real UK gross disposable national income at market prices, constant border estimate  \
# 0                                          1843502.0
# 1                                          1793997.0
# 2                                          1749880.0
# 3                                          1702359.0
# 4                                          1681556.0
#
#    Real consumption  ...  UK Public sector debt.1  UK Public sector debt.2  \
# 0         1223627.0  ...                     87.7                     87.7
# 1         1190789.0  ...                     86.0                     86.0
# 2         1163136.0  ...                     85.4                     85.4
# 3         1138546.0  ...                     83.6                     83.6
# 4         1121061.0  ...                     80.6                     80.6
#
#    Central Government Gross Debt  Central Government Gross Debt.1  \
# 0                      1628685.0                        2070854.0
# 1                      1581986.0                        2005548.0
# 2                      1502068.0                        1736853.0
# 3                      1404319.0                        1731089.0
# 4                      1329598.0                        1569916.0
#
#    Trade deficit  Trade deficit.1  Current account   Current account .1  \
# 0       -37026.0            -1.91          -84504.0                -4.4
# 1       -29788.0            -1.59          -80233.0                -4.3
# 2       -36223.0            -1.99          -84998.0                -4.7
# 3       -39238.0            -2.26          -76442.0                -4.4
# 4       -37334.0            -2.23          -61433.0                -3.7
#
#    Current account deficit including estimated non-monetary bullion flows  \
# 0                                           -84504.0
# 1                                           -80233.0
# 2                                           -84998.0
# 3                                           -76442.0
# 4                                           -61433.0
#
#    Current account deficit including estimated non-monetary bullion flows.1
# 0                                               -4.4
# 1                                               -4.3
# 2                                               -4.7
# 3                                               -4.4
# 4                                               -3.7
#
# [5 rows x 77 columns]

# %%
#1.1 Variables we are going to use

# %%
#"Real GDP of England at market prices"
#Real consumption
#Real investment
#Employment
#$ Oil prices
#UK Public sector debt
#Trade deficit
#Public sector Total Managed Expenditure
#M1
#Capital Services, whole economy

# %%
#1.2 Creating de DF
df1 = df[["Description", "Real GDP of England at market prices", "Real consumption", "Real investment",
            "Employment", "$ Oil prices", "UK Public sector debt", "Terms of Trade",
            "Public sector Total Managed Expenditure", "M1", "House price index"]]

# %%
df1.head()
# Out:
#    Description  Real GDP of England at market prices  Real consumption  \
# 0         2016                             1672084.0         1223627.0
# 1         2015                             1642802.0         1190789.0
# 2         2014                             1604169.0         1163136.0
# 3         2013                             1551553.0         1138546.0
# 4         2012                             1530435.0         1121061.0
#
#    Real investment  Employment  $ Oil prices  UK Public sector debt  \
# 0         310816.0     31741.0         43.82              1701800.0
# 1         309144.0     31296.0         52.39              1610500.0
# 2         298872.0     30757.0         98.93              1556000.0
# 3         280224.0     30044.0        108.66              1454000.0
# 4         271534.0     29696.0        111.67              1349700.0
#
#    Terms of Trade  Public sector Total Managed Expenditure        M1  \
# 0          102.31                                 766473.0  802754.0
# 1          102.27                                 752904.0  780106.0
# 2          101.54                                 751173.0  734574.0
# 3          100.00                                 730662.0  683952.0
# 4           97.81                                 735765.0  617849.0
#
#    House price index
# 0             111.36
# 1             103.79
# 2              97.96
# 3              90.68
# 4              88.40

# %%
#1.4 Change the name of columns
df1.rename(columns={
    "Description": "Year",
    "Real GDP of England at market prices": "Real_GDP",
    "Real consumption": "Consumption",
    "Real investment": "Investment",
    "Employment": "Employment",
    "$ Oil prices": "Oil_Prices",
    "UK Public sector debt": "Public_Sector_Debt",
    "Terms of Trade": "TOT",
    "Public sector Total Managed Expenditure": "Total_Managed_Expenditure",
    "M1": "M1",
    "House price index": "HousePrice"
}, inplace=True)

# %%
df1.head()
# Out:
#    Year   Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# 0  2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 1  2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2  2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 3  2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 4  2012  1530435.0    1121061.0    271534.0     29696.0      111.67
#
#    Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  HousePrice
# 0           1701800.0  102.31                   766473.0  802754.0      111.36
# 1           1610500.0  102.27                   752904.0  780106.0      103.79
# 2           1556000.0  101.54                   751173.0  734574.0       97.96
# 3           1454000.0  100.00                   730662.0  683952.0       90.68
# 4           1349700.0   97.81                   735765.0  617849.0       88.40

# %%
#1.5Display the DataFrame with the "Year" column as the index
df1.set_index("Year",inplace=True)

# %%
display(df1)
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# ...         ...          ...         ...         ...         ...
# 1213        NaN          NaN         NaN         NaN         NaN
# 1212        NaN          NaN         NaN         NaN         NaN
# 1211        NaN          NaN         NaN         NaN         NaN
# 1210        NaN          NaN         NaN         NaN         NaN
# 1209        NaN          NaN         NaN         NaN         NaN
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2016           1701800.0  102.31                   766473.0  802754.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# ...                  ...     ...                        ...       ...
# 1213                 NaN     NaN                        NaN       NaN
# 1212                 NaN     NaN                        NaN       NaN
# 1211                 NaN     NaN                        NaN       NaN
# 1210                 NaN     NaN                        NaN       NaN
# 1209                 NaN     NaN                        NaN       NaN
#
#       HousePrice
# Year
# 2016      111.36
# 2015      103.79
# 2014       97.96
# 2013       90.68
# 2012       88.40
# ...          ...
# 1213         NaN
# 1212         NaN
# 1211         NaN
# 1210         NaN
# 1209         NaN
#
# [808 rows x 10 columns]

# %%
# Null Values, we do not need 
df1.isna().sum()
# Out:
# Real_GDP                      61
# Consumption                  621
# Investment                   621
# Employment                   646
# Oil_Prices                   652
# Public_Sector_Debt           482
# TOT                          563
# Total_Managed_Expenditure    691
# M1                           713
# HousePrice                   636
# dtype: int64

# %%
df1.dropna(axis=0, inplace=True)

# %%
df1 # We end up with a database with 95 years
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# ...         ...          ...         ...         ...         ...
# 1926   191950.0     156780.0     16743.0     18537.0        1.88
# 1925   198406.0     155908.0     17250.0     18532.0        1.68
# 1924   191378.0     153246.0     15141.0     18322.0        1.43
# 1923   182423.0     148335.0     12990.0     18051.0        1.34
# 1922   176904.0     143929.0     12653.0     17821.0        1.61
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2016           1701800.0  102.31                   766473.0  802754.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# ...                  ...     ...                        ...       ...
# 1926              7648.0   92.39                     1155.0    1476.0
# 1925              7642.0   88.37                     1096.0    1491.0
# 1924              7676.0   91.05                     1041.0    1519.0
# 1923              7734.0   94.44                     1048.0    1537.0
# 1922              7790.0   97.57                     1172.0    1563.0
#
#       HousePrice
# Year
# 2016      111.36
# 2015      103.79
# 2014       97.96
# 2013       90.68
# 2012       88.40
# ...          ...
# 1926        0.26
# 1925        0.26
# 1924        0.24
# 1923        0.23
# 1922        0.21
#
# [95 rows x 10 columns]

# %%
df1.describe()
# Out:
#            Real_GDP   Consumption     Investment    Employment  Oil_Prices  \
# count  9.500000e+01  9.500000e+01      95.000000     95.000000   95.000000
# mean   7.104196e+05  4.907425e+05  132098.778947  24539.884211   18.111053
# std    4.583850e+05  3.384436e+05  100501.882425   3208.878998   27.096773
# min    1.769040e+05  1.439290e+05    7170.000000  17821.000000    0.650000
# 25%    3.146170e+05  2.010925e+05   24271.500000  23398.500000    1.695000
# 50%    5.969050e+05  3.627140e+05  138923.000000  24725.000000    2.080000
# 75%    1.020780e+06  6.941740e+05  222956.500000  26065.000000   24.085000
# max    1.672084e+06  1.223627e+06  312995.000000  31741.000000  111.670000
#
#        Public_Sector_Debt         TOT  Total_Managed_Expenditure  \
# count        9.500000e+01   95.000000                  95.000000
# mean         2.199856e+05   95.531895              165642.757895
# std          3.879074e+05    5.991166              234999.419001
# min          7.586000e+03   78.520000                1041.000000
# 25%          2.436850e+04   91.780000                4925.500000
# 50%          3.364200e+04   95.690000               20233.000000
# 75%          2.138755e+05   99.040000              283823.500000
# max          1.701800e+06  107.170000              766473.000000
#
#                   M1  HousePrice
# count      95.000000   95.000000
# mean   125693.768421   21.134316
# std    210737.941426   31.944239
# min      1383.000000    0.210000
# 25%      5397.500000    0.580000
# 50%      9098.000000    2.080000
# 75%    147491.500000   30.400000
# max    802754.000000  111.360000

# %%
df1 = df1.apply(pd.to_numeric, errors='coerce')

# Now, run describe() again
print(df1.describe())
# Out:
#            Real_GDP   Consumption     Investment    Employment  Oil_Prices  \
# count  9.500000e+01  9.500000e+01      95.000000     95.000000   95.000000
# mean   7.104196e+05  4.907425e+05  132098.778947  24539.884211   18.111053
# std    4.583850e+05  3.384436e+05  100501.882425   3208.878998   27.096773
# min    1.769040e+05  1.439290e+05    7170.000000  17821.000000    0.650000
# 25%    3.146170e+05  2.010925e+05   24271.500000  23398.500000    1.695000
# 50%    5.969050e+05  3.627140e+05  138923.000000  24725.000000    2.080000
# 75%    1.020780e+06  6.941740e+05  222956.500000  26065.000000   24.085000
# max    1.672084e+06  1.223627e+06  312995.000000  31741.000000  111.670000
#
#        Public_Sector_Debt         TOT  Total_Managed_Expenditure  \
# count        9.500000e+01   95.000000                  95.000000
# mean         2.199856e+05   95.531895              165642.757895
# std          3.879074e+05    5.991166              234999.419001
# min          7.586000e+03   78.520000                1041.000000
# 25%          2.436850e+04   91.780000                4925.500000
# 50%          3.364200e+04   95.690000               20233.000000
# 75%          2.138755e+05   99.040000              283823.500000
# max          1.701800e+06  107.170000              766473.000000
#
#                   M1  HousePrice
# count      95.000000   95.000000
# mean   125693.768421   21.134316
# std    210737.941426   31.944239
# min      1383.000000    0.210000
# 25%      5397.500000    0.580000
# 50%      9098.000000    2.080000
# 75%    147491.500000   30.400000
# max    802754.000000  111.360000

# %%
#  Now we have a 10-variable data set with a total of 95 year observations starting on 1922

# %%
 fig, axes = plt.subplots(nrows=5, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1[df1.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title(df1.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# We can see that none of the series is stationary, all of them shows a Trend,
# All the varibles got volatile after the 2ww

# %%
### Seasonal decompose

# %%
df1_reverse = df1[::-1]
df1=df1_reverse

# %%
df1=df1_reverse

# %%
for i, ax in enumerate(axes.flatten()):
    data = seasonal_decompose(df1[df1.columns[i]], model= 'additive',period=1,)
    ax = data.plot()
    
plt.tight_layout();

# %%
##ACF

# %%
for i in df1:
    sgt.plot_acf(df1[i],lags=30, zero=False)
    plt.title("ACF for %s"%i)
    plt.show()
# Why we use ACF and what can we infer from below

# %%
for i in df1:
    sgt.plot_pacf(df1[i],lags=15, zero=False)
    plt.title("PACF for %s"%i)
    plt.show()
# Why we use ACF and what can we infer from below

# %%
def adf_test(timeseries, name):
    dftest = sts.adfuller(timeseries)
    dfoutput = pd.Series(dftest[0:4], 
                         index=['Test Statistic','p-value','Lags Used','Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print('\033[1m{:10s}\033[0m'.format(name))
    print(dfoutput)
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=4).mean()
    rolstd = timeseries.rolling(window=4).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.grid()
    plt.show(block=False)

# %%
for i in df1:
    adf_test(df1[i], i)
# Out:
# Real_GDP
# Test Statistic           2.693625
# p-value                  0.999087
# Lags Used                2.000000
# Observations Used       92.000000
# Critical Value (1%)     -3.503515
# Critical Value (5%)     -2.893508
# Critical Value (10%)    -2.583824
# dtype: float64
# Consumption
# Test Statistic           2.051147
# p-value                  0.998736
# Lags Used                1.000000
# Observations Used       93.000000
# Critical Value (1%)     -3.502705
# Critical Value (5%)     -2.893158
# Critical Value (10%)    -2.583637
# dtype: float64
# Investment
# Test Statistic           0.466425
# p-value                  0.983816
# Lags Used                2.000000
# Observations Used       92.000000
# Critical Value (1%)     -3.503515
# Critical Value (5%)     -2.893508
# Critical Value (10%)    -2.583824
# dtype: float64
# Employment
# Test Statistic          -0.724370
# p-value                  0.840336
# Lags Used                1.000000
# Observations Used       93.000000
# Critical Value (1%)     -3.502705
# Critical Value (5%)     -2.893158
# Critical Value (10%)    -2.583637
# dtype: float64
# Oil_Prices
# Test Statistic          -1.107090
# p-value                  0.712236
# Lags Used                9.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# Public_Sector_Debt
# Test Statistic           5.491482
# p-value                  1.000000
# Lags Used               10.000000
# Observations Used       84.000000
# Critical Value (1%)     -3.510712
# Critical Value (5%)     -2.896616
# Critical Value (10%)    -2.585482
# dtype: float64
# TOT
# Test Statistic          -2.859945
# p-value                  0.050208
# Lags Used                3.000000
# Observations Used       91.000000
# Critical Value (1%)     -3.504343
# Critical Value (5%)     -2.893866
# Critical Value (10%)    -2.584015
# dtype: float64
# Total_Managed_Expenditure
# Test Statistic           1.305582
# p-value                  0.996640
# Lags Used                3.000000
# Observations Used       91.000000
# Critical Value (1%)     -3.504343
# Critical Value (5%)     -2.893866
# Critical Value (10%)    -2.584015
# dtype: float64
# M1
# Test Statistic           0.831598
# p-value                  0.992129
# Lags Used               12.000000
# Observations Used       82.000000
# Critical Value (1%)     -3.512738
# Critical Value (5%)     -2.897490
# Critical Value (10%)    -2.585949
# dtype: float64
# HousePrice
# Test Statistic           5.312494
# p-value                  1.000000
# Lags Used               11.000000
# Observations Used       83.000000
# Critical Value (1%)     -3.511712
# Critical Value (5%)     -2.897048
# Critical Value (10%)    -2.585713
# dtype: float64

# %%
#4 Test VS Train 
size = int(len(df1) * 0.93)
df1_train = df1.iloc[:size]
df1_test = df1.iloc[size:]

# %%
df1_train
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 1922   176904.0     143929.0     12653.0     17821.0        1.61
# 1923   182423.0     148335.0     12990.0     18051.0        1.34
# 1924   191378.0     153246.0     15141.0     18322.0        1.43
# 1925   198406.0     155908.0     17250.0     18532.0        1.68
# 1926   191950.0     156780.0     16743.0     18537.0        1.88
# ...         ...          ...         ...         ...         ...
# 2005  1464210.0    1095514.0    287077.0     28850.0       54.52
# 2006  1500097.0    1113261.0    296121.0     29138.0       65.14
# 2007  1538059.0    1145189.0    312995.0     29378.0       72.39
# 2008  1531690.0    1137565.0    292575.0     29628.0       97.26
# 2009  1463182.0    1100941.0    248099.0     29156.0       61.67
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 1922              7790.0   97.57                     1172.0    1563.0
# 1923              7734.0   94.44                     1048.0    1537.0
# 1924              7676.0   91.05                     1041.0    1519.0
# 1925              7642.0   88.37                     1096.0    1491.0
# 1926              7648.0   92.39                     1155.0    1476.0
# ...                  ...     ...                        ...       ...
# 2005            492200.0  100.46                   534479.0  465844.0
# 2006            527300.0   99.58                   561242.0  510573.0
# 2007            562500.0   98.83                   590694.0  544073.0
# 2008            733300.0   95.51                   643692.0  534237.0
# 2009            938900.0   97.10                   686259.0  574379.0
#
#       HousePrice
# Year
# 1922        0.21
# 1923        0.23
# 1924        0.24
# 1925        0.26
# 1926        0.26
# ...          ...
# 2005       81.94
# 2006       88.38
# 2007       97.13
# 2008       92.76
# 2009       84.52
#
# [88 rows x 10 columns]

# %%
df1_test
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2010  1494588.0    1107273.0    260396.0     29228.0       79.50
# 2011  1514583.0    1102262.0    265327.0     29376.0      111.26
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2010           1136900.0   98.40                   712512.0  580083.0
# 2011           1240700.0   97.42                   715649.0  578774.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2016           1701800.0  102.31                   766473.0  802754.0
#
#       HousePrice
# Year
# 2010       89.35
# 2011       88.05
# 2012       88.40
# 2013       90.68
# 2014       97.96
# 2015      103.79
# 2016      111.36

# %%
##5 Data Transformation
# We are going to apply logaritms and then im going to apply differeces to make the variables stacionary

# %%
df1_train_log = np.log(df1_train)

# %%
 fig, axes = plt.subplots(nrows=5, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1_train_log[df1_train_log.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title(df1_train_log.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Now  we appy first doifferences and then we will run ADF test to see if the variables are still stationary

# %%
df1_train_log_diff = (df1_train_log).diff().dropna()

# %%
df1_train_log_diff
# Out:
#       Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 1923  0.030721     0.030153    0.026285    0.012824   -0.183565
# 1924  0.047922     0.032571    0.153226    0.014901    0.065005
# 1925  0.036065     0.017222    0.130406    0.011396    0.161119
# 1926 -0.033081     0.005577   -0.029832    0.000270    0.112478
# 1927  0.078479     0.042416    0.109687    0.028767   -0.368908
# ...        ...          ...         ...         ...         ...
# 2005  0.032020     0.029094    0.034701    0.011154    0.353901
# 2006  0.024214     0.016070    0.031018    0.009933    0.177971
# 2007  0.024991     0.028276    0.055419    0.008203    0.105529
# 2008 -0.004150    -0.006680   -0.067466    0.008474    0.295320
# 2009 -0.045758    -0.032725   -0.164893   -0.016059   -0.455590
#
#       Public_Sector_Debt       TOT  Total_Managed_Expenditure        M1  \
# Year
# 1923           -0.007215 -0.032605                  -0.111828 -0.016775
# 1924           -0.007528 -0.036556                  -0.006702 -0.011780
# 1925           -0.004439 -0.029876                   0.051485 -0.018605
# 1926            0.000785  0.044486                   0.052433 -0.010111
# 1927           -0.001570 -0.004121                  -0.020114  0.012121
# ...                  ...       ...                        ...       ...
# 2005            0.092531 -0.006153                   0.074948  0.121472
# 2006            0.068885 -0.008798                   0.048860  0.091683
# 2007            0.064621 -0.007560                   0.051146  0.063550
# 2008            0.265164 -0.034170                   0.085922 -0.018244
# 2009            0.247154  0.016510                   0.064035  0.072450
#
#       HousePrice
# Year
# 1923    0.090972
# 1924    0.042560
# 1925    0.080043
# 1926    0.000000
# 1927    0.000000
# ...          ...
# 2005    0.053389
# 2006    0.075658
# 2007    0.094405
# 2008   -0.046035
# 2009   -0.093027
#
# [87 rows x 10 columns]

# %%
 fig, axes = plt.subplots(nrows=int(len(df1_train_log_diff.columns)/2), ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1_train_log_diff[df1_train_log_diff.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title("diff-log-" + df1_train_log_diff.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Then i aply dkf test to the transformed variables 

for i in df1_train_log_diff:
    adf_test(df1_train_log_diff[i], i)
# Out:
# Real_GDP
# Test Statistic          -5.350074
# p-value                  0.000004
# Lags Used                1.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# Consumption
# Test Statistic          -5.294196
# p-value                  0.000006
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# Investment
# Test Statistic         -5.955325e+00
# p-value                 2.099916e-07
# Lags Used               1.000000e+00
# Observations Used       8.500000e+01
# Critical Value (1%)    -3.509736e+00
# Critical Value (5%)    -2.896195e+00
# Critical Value (10%)   -2.585258e+00
# dtype: float64
# Employment
# Test Statistic          -4.956223
# p-value                  0.000027
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# Oil_Prices
# Test Statistic         -8.998631e+00
# p-value                 6.589403e-15
# Lags Used               0.000000e+00
# Observations Used       8.600000e+01
# Critical Value (1%)    -3.508783e+00
# Critical Value (5%)    -2.895784e+00
# Critical Value (10%)   -2.585038e+00
# dtype: float64
# Public_Sector_Debt
# Test Statistic          -3.542169
# p-value                  0.006968
# Lags Used                1.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# TOT
# Test Statistic         -7.650672e+00
# p-value                 1.792873e-11
# Lags Used               1.000000e+00
# Observations Used       8.500000e+01
# Critical Value (1%)    -3.509736e+00
# Critical Value (5%)    -2.896195e+00
# Critical Value (10%)   -2.585258e+00
# dtype: float64
# Total_Managed_Expenditure
# Test Statistic          -4.738610
# p-value                  0.000071
# Lags Used                5.000000
# Observations Used       81.000000
# Critical Value (1%)     -3.513790
# Critical Value (5%)     -2.897943
# Critical Value (10%)    -2.586191
# dtype: float64
# M1
# Test Statistic          -4.267299
# p-value                  0.000506
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# HousePrice
# Test Statistic          -3.540713
# p-value                  0.007001
# Lags Used                3.000000
# Observations Used       83.000000
# Critical Value (1%)     -3.511712
# Critical Value (5%)     -2.897048
# Critical Value (10%)    -2.585713
# dtype: float64

# %%
# all Variables are now stationary, but not the Capital, should we apply second differences to that ?

# %%
### ACF
for i in df1_train_log_diff:
    sgt.plot_acf(df1_train_log_diff[i], lags = 20, zero=False)
    plt.title('ACF for %s' % i) 
    plt.show()

# %%
for i in df1_train_log_diff:
    sgt.plot_pacf(df1_train_log_diff[i], lags = 20, zero=False)
    plt.title('PACF for %s' % i) 
    plt.show()

# %%
##Granger Causality test#
lag=int(((int(len(df1_train.index)))/3)/int(len(df1_train.columns)))
lag
# Out:
# 2

# %% [markdown]
# ### Granjer test

# %%
maxlag=lag

test = 'ssr_chi2test'


def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables) #creating a df with 0 to store granger results
    for c in df.columns:
        for r in df.index:
            test_result = sts.grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)] #This line extracts the p-values from the Granger causality test results. It iterates over each lag from 1 to maxlag (assuming maxlag is defined somewhere), retrieves the p-value from the test results, and rounds it to 4 decimal places.
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
grangers_causation_matrix(df1_train_log_diff, variables = df1_train_log_diff.columns)
# Out:
#                              Real_GDP_x  Consumption_x  Investment_x  \
# Real_GDP_y                       1.0000         0.4509        0.2788
# Consumption_y                    0.1486         1.0000        0.2322
# Investment_y                     0.0028         0.0006        1.0000
# Employment_y                     0.0013         0.6862        0.0128
# Oil_Prices_y                     0.1347         0.0195        0.0243
# Public_Sector_Debt_y             0.3822         0.0976        0.0932
# TOT_y                            0.2818         0.0003        0.0974
# Total_Managed_Expenditure_y      0.0909         0.0848        0.0121
# M1_y                             0.5571         0.0540        0.0055
# HousePrice_y                     0.7398         0.0648        0.0106
#
#                              Employment_x  Oil_Prices_x  Public_Sector_Debt_x  \
# Real_GDP_y                         0.3392        0.0551                0.1472
# Consumption_y                      0.0081        0.4725                0.1984
# Investment_y                       0.0160        0.1019                0.0156
# Employment_y                       1.0000        0.0535                0.3774
# Oil_Prices_y                       0.6106        1.0000                0.9050
# Public_Sector_Debt_y               0.4724        0.1372                1.0000
# TOT_y                              0.1581        0.0497                0.5530
# Total_Managed_Expenditure_y        0.0028        0.1180                0.1103
# M1_y                               0.3682        0.5122                0.0153
# HousePrice_y                       0.1640        0.2674                0.3587
#
#                               TOT_x  Total_Managed_Expenditure_x    M1_x  \
# Real_GDP_y                   0.1059                       0.2438  0.0095
# Consumption_y                0.1006                       0.1066  0.0233
# Investment_y                 0.7609                       0.0004  0.5312
# Employment_y                 0.8188                       0.8923  0.0098
# Oil_Prices_y                 0.0519                       0.9096  0.0169
# Public_Sector_Debt_y         0.1683                       0.0050  0.5390
# TOT_y                        1.0000                       0.0622  0.7954
# Total_Managed_Expenditure_y  0.0634                       1.0000  0.4485
# M1_y                         0.3050                       0.0048  1.0000
# HousePrice_y                 0.2318                       0.2968  0.0000
#
#                              HousePrice_x
# Real_GDP_y                         0.1456
# Consumption_y                      0.8151
# Investment_y                       0.6816
# Employment_y                       0.0245
# Oil_Prices_y                       0.0000
# Public_Sector_Debt_y               0.3067
# TOT_y                              0.0434
# Total_Managed_Expenditure_y        0.1794
# M1_y                               0.7776
# HousePrice_y                       1.0000

# %% [markdown]
# ###  VAR model

# %%
 #Initiate VAR model
var_model = VAR(endog=df1_train_log_diff)
res_var = var_model.select_order(maxlags=2, trend='ct')
res_var.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Based on AIC Criteria we swelect 1 lag fo our model

# %%
 var_model_fit = var_model.fit(maxlags=1, ic='aic')
var_model_fit.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 11, Mar, 2024
# Time:                     16:52:31
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -60.2321
# Nobs:                     86.0000    HQIC:                  -62.1079
# Log likelihood:           1614.68    FPE:                3.04994e-28
# AIC:                     -63.3714    Det(Omega_mle):     9.15289e-29
# --------------------------------------------------------------------
# Results for equation Real_GDP
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.017423         0.007241            2.406           0.016
# L1.Real_GDP                          0.170356         0.168249            1.013           0.311
# L1.Consumption                      -0.035293         0.207456           -0.170           0.865
# L1.Investment                        0.037719         0.027870            1.353           0.176
# L1.Employment                        0.134219         0.255875            0.525           0.600
# L1.Oil_Prices                       -0.017443         0.012740           -1.369           0.171
# L1.Public_Sector_Debt               -0.121593         0.052014           -2.338           0.019
# L1.TOT                               0.047364         0.092087            0.514           0.607
# L1.Total_Managed_Expenditure         0.084519         0.059683            1.416           0.157
# L1.M1                                0.113978         0.055089            2.069           0.039
# L1.HousePrice                       -0.077292         0.049821           -1.551           0.121
# ===============================================================================================
#
# Results for equation Consumption
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.023630         0.006338            3.728           0.000
# L1.Real_GDP                          0.186293         0.147265            1.265           0.206
# L1.Consumption                       0.055961         0.181582            0.308           0.758
# L1.Investment                       -0.037836         0.024394           -1.551           0.121
# L1.Employment                       -0.699777         0.223963           -3.125           0.002
# L1.Oil_Prices                        0.008166         0.011151            0.732           0.464
# L1.Public_Sector_Debt               -0.071266         0.045527           -1.565           0.117
# L1.TOT                               0.105860         0.080602            1.313           0.189
# L1.Total_Managed_Expenditure        -0.138472         0.052239           -2.651           0.008
# L1.M1                                0.179156         0.048218            3.716           0.000
# L1.HousePrice                        0.008202         0.043607            0.188           0.851
# ===============================================================================================
#
# Results for equation Investment
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.045404         0.032017            1.418           0.156
# L1.Real_GDP                         -1.359759         0.743910           -1.828           0.068
# L1.Consumption                       1.842746         0.917260            2.009           0.045
# L1.Investment                        0.109466         0.123225            0.888           0.374
# L1.Employment                       -1.110085         1.131345           -0.981           0.326
# L1.Oil_Prices                       -0.083547         0.056329           -1.483           0.138
# L1.Public_Sector_Debt               -0.421021         0.229979           -1.831           0.067
# L1.TOT                              -1.030128         0.407160           -2.530           0.011
# L1.Total_Managed_Expenditure         0.065092         0.263886            0.247           0.805
# L1.M1                                0.248714         0.243574            1.021           0.307
# L1.HousePrice                       -0.203043         0.220282           -0.922           0.357
# ===============================================================================================
#
# Results for equation Employment
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                               -0.000687         0.003613           -0.190           0.849
# L1.Real_GDP                          0.129074         0.083954            1.537           0.124
# L1.Consumption                      -0.075015         0.103517           -0.725           0.469
# L1.Investment                        0.030988         0.013907            2.228           0.026
# L1.Employment                        0.439580         0.127678            3.443           0.001
# L1.Oil_Prices                       -0.007177         0.006357           -1.129           0.259
# L1.Public_Sector_Debt               -0.012787         0.025954           -0.493           0.622
# L1.TOT                               0.018386         0.045950            0.400           0.689
# L1.Total_Managed_Expenditure        -0.005751         0.029781           -0.193           0.847
# L1.M1                                0.063176         0.027488            2.298           0.022
# L1.HousePrice                       -0.024655         0.024860           -0.992           0.321
# ===============================================================================================
#
# Results for equation Oil_Prices
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                               -0.160603         0.063849           -2.515           0.012
# L1.Real_GDP                          0.439608         1.483510            0.296           0.767
# L1.Consumption                       2.232417         1.829206            1.220           0.222
# L1.Investment                        0.422977         0.245737            1.721           0.085
# L1.Employment                        1.021107         2.256135            0.453           0.651
# L1.Oil_Prices                       -0.175648         0.112333           -1.564           0.118
# L1.Public_Sector_Debt                0.584469         0.458626            1.274           0.203
# L1.TOT                              -0.873673         0.811962           -1.076           0.282
# L1.Total_Managed_Expenditure         0.586810         0.526244            1.115           0.265
# L1.M1                               -0.449944         0.485737           -0.926           0.354
# L1.HousePrice                        1.181809         0.439287            2.690           0.007
# ===============================================================================================
#
# Results for equation Public_Sector_Debt
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.006510         0.012855            0.506           0.613
# L1.Real_GDP                         -0.009583         0.298671           -0.032           0.974
# L1.Consumption                       0.227153         0.368269            0.617           0.537
# L1.Investment                       -0.055146         0.049473           -1.115           0.265
# L1.Employment                       -0.182025         0.454221           -0.401           0.689
# L1.Oil_Prices                        0.002320         0.022616            0.103           0.918
# L1.Public_Sector_Debt                0.724586         0.092334            7.847           0.000
# L1.TOT                              -0.174836         0.163470           -1.070           0.285
# L1.Total_Managed_Expenditure         0.185735         0.105947            1.753           0.080
# L1.M1                               -0.131992         0.097792           -1.350           0.177
# L1.HousePrice                        0.057159         0.088440            0.646           0.518
# ===============================================================================================
#
# Results for equation TOT
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.021633         0.009296            2.327           0.020
# L1.Real_GDP                          0.008663         0.215998            0.040           0.968
# L1.Consumption                      -0.613048         0.266331           -2.302           0.021
# L1.Investment                       -0.007097         0.035779           -0.198           0.843
# L1.Employment                       -0.068764         0.328492           -0.209           0.834
# L1.Oil_Prices                        0.036814         0.016356            2.251           0.024
# L1.Public_Sector_Debt               -0.077026         0.066776           -1.154           0.249
# L1.TOT                               0.248056         0.118221            2.098           0.036
# L1.Total_Managed_Expenditure        -0.057813         0.076621           -0.755           0.451
# L1.M1                                0.060811         0.070723            0.860           0.390
# L1.HousePrice                       -0.051296         0.063960           -0.802           0.423
# ===============================================================================================
#
# Results for equation Total_Managed_Expenditure
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.005730         0.019949            0.287           0.774
# L1.Real_GDP                         -0.308288         0.463506           -0.665           0.506
# L1.Consumption                       0.887875         0.571515            1.554           0.120
# L1.Investment                        0.037070         0.076778            0.483           0.629
# L1.Employment                        1.395727         0.704904            1.980           0.048
# L1.Oil_Prices                        0.027968         0.035097            0.797           0.426
# L1.Public_Sector_Debt               -0.091924         0.143292           -0.642           0.521
# L1.TOT                              -0.303738         0.253688           -1.197           0.231
# L1.Total_Managed_Expenditure         0.848925         0.164419            5.163           0.000
# L1.M1                               -0.193680         0.151763           -1.276           0.202
# L1.HousePrice                        0.010940         0.137250            0.080           0.936
# ===============================================================================================
#
# Results for equation M1
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.010922         0.012900            0.847           0.397
# L1.Real_GDP                         -0.482315         0.299717           -1.609           0.108
# L1.Consumption                       0.470683         0.369559            1.274           0.203
# L1.Investment                       -0.040589         0.049647           -0.818           0.414
# L1.Employment                        0.620852         0.455813            1.362           0.173
# L1.Oil_Prices                       -0.040212         0.022695           -1.772           0.076
# L1.Public_Sector_Debt                0.112195         0.092657            1.211           0.226
# L1.TOT                              -0.133454         0.164043           -0.814           0.416
# L1.Total_Managed_Expenditure         0.224656         0.106318            2.113           0.035
# L1.M1                                0.523143         0.098135            5.331           0.000
# L1.HousePrice                        0.007690         0.088750            0.087           0.931
# ===============================================================================================
#
# Results for equation HousePrice
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                               -0.012520         0.014728           -0.850           0.395
# L1.Real_GDP                          0.158134         0.342192            0.462           0.644
# L1.Consumption                       0.469933         0.421932            1.114           0.265
# L1.Investment                        0.033599         0.056683            0.593           0.553
# L1.Employment                       -0.687507         0.520409           -1.321           0.186
# L1.Oil_Prices                       -0.014839         0.025911           -0.573           0.567
# L1.Public_Sector_Debt                0.008827         0.105788            0.083           0.933
# L1.TOT                               0.073240         0.187290            0.391           0.696
# L1.Total_Managed_Expenditure         0.020294         0.121386            0.167           0.867
# L1.M1                                0.505179         0.112042            4.509           0.000
# L1.HousePrice                        0.469807         0.101328            4.637           0.000
# ===============================================================================================
#
# Correlation matrix of residuals
#                              Real_GDP  Consumption  Investment  Employment  Oil_Prices  Public_Sector_Debt       TOT  Total_Managed_Expenditure        M1  HousePrice
# Real_GDP                     1.000000     0.055146    0.229502    0.567357    0.034993           -0.145172 -0.423104                   0.331902  0.204472    0.197966
# Consumption                  0.055146     1.000000    0.472810   -0.057112   -0.065395           -0.435125  0.285292                  -0.715220  0.051799    0.240705
# Investment                   0.229502     0.472810    1.000000   -0.162988   -0.069928           -0.217049  0.148546                  -0.345228  0.023233    0.030690
# Employment                   0.567357    -0.057112   -0.162988    1.000000    0.124439           -0.016587 -0.297967                   0.209162  0.033080    0.127839
# Oil_Prices                   0.034993    -0.065395   -0.069928    0.124439    1.000000            0.214208 -0.145829                   0.103547 -0.022026   -0.046411
# Public_Sector_Debt          -0.145172    -0.435125   -0.217049   -0.016587    0.214208            1.000000 -0.217379                   0.388783 -0.010954   -0.254840
# TOT                         -0.423104     0.285292    0.148546   -0.297967   -0.145829           -0.217379  1.000000                  -0.330716 -0.063935   -0.035022
# Total_Managed_Expenditure    0.331902    -0.715220   -0.345228    0.209162    0.103547            0.388783 -0.330716                   1.000000  0.094649    0.090178
# M1                           0.204472     0.051799    0.023233    0.033080   -0.022026           -0.010954 -0.063935                   0.094649  1.000000    0.135219
# HousePrice                   0.197966     0.240705    0.030690    0.127839   -0.046411           -0.254840 -0.035022                   0.090178  0.135219    1.000000

# %%
## Check for serial correlation of residuals
dw_check_var = durbin_watson(var_model_fit.resid)

for col, val in zip(df1_train_log_diff.columns, dw_check_var):
    print("Durbin-Watson statistic for:")
    print(col, '-->', round(val, 2))
    print("----------------------------")
# Out:
# Durbin-Watson statistic for:
# Real_GDP --> 1.88
# ----------------------------
# Durbin-Watson statistic for:
# Consumption --> 2.04
# ----------------------------
# Durbin-Watson statistic for:
# Investment --> 2.02
# ----------------------------
# Durbin-Watson statistic for:
# Employment --> 2.08
# ----------------------------
# Durbin-Watson statistic for:
# Oil_Prices --> 1.87
# ----------------------------
# Durbin-Watson statistic for:
# Public_Sector_Debt --> 1.72
# ----------------------------
# Durbin-Watson statistic for:
# TOT --> 1.89
# ----------------------------
# Durbin-Watson statistic for:
# Total_Managed_Expenditure --> 1.84
# ----------------------------
# Durbin-Watson statistic for:
# M1 --> 2.23
# ----------------------------
# Durbin-Watson statistic for:
# HousePrice --> 1.81
# ----------------------------

# %%
 #Get the lag order
lag_order = var_model_fit.k_ar
print(lag_order)
# Out:
# 1

# %%
#Input data for forecasting
pred_input = df1_train_log_diff.values[-lag_order:]
pred_input
# Out:
# array([[-0.04575818, -0.03272474, -0.16489318, -0.01605914, -0.45559022,
#          0.24715408,  0.01651042,  0.06403476,  0.0724499 , -0.09302732]])

# %%
#Forecasting
var_pred = var_model_fit.forecast(y=pred_input, steps=len(df1_test))

df_var_pred = pd.DataFrame(var_pred, index = df1_test.index, columns = df1_train_log_diff.columns + '_1d')

df_var_pred
# Out:
#       Real_GDP_1d  Consumption_1d  Investment_1d  Employment_1d  \
# Year
# 2010     0.001944        0.014515       0.005171      -0.009392
# 2011     0.009931        0.042848       0.034819       0.001942
# 2012     0.006336        0.043339       0.072724       0.003348
# 2013     0.007977        0.036673       0.096270       0.002258
# 2014     0.013521        0.031077       0.092186       0.002372
# 2015     0.018341        0.027577       0.075037       0.003202
# 2016     0.021349        0.025371       0.059150       0.003938
#
#       Oil_Prices_1d  Public_Sector_Debt_1d    TOT_1d  \
# Year
# 2010      -0.234827               0.183685  0.017334
# 2011      -0.103376               0.117577  0.005086
# 2012       0.013087               0.074818 -0.009305
# 2013       0.051639               0.052738 -0.009819
# 2014       0.057800               0.043198 -0.005840
# 2015       0.051903               0.040946 -0.002342
# 2016       0.043373               0.042653 -0.000361
#
#       Total_Managed_Expenditure_1d     M1_1d  HousePrice_1d
# Year
# 2010                     -0.038911  0.109730      -0.025287
# 2011                     -0.078177  0.086982       0.050379
# 2012                     -0.053193  0.071091       0.077989
# 2013                     -0.012132  0.062342       0.080248
# 2014                      0.020636  0.057487       0.075587
# 2015                      0.042513  0.055352       0.069756
# 2016                      0.056344  0.055862       0.064677

# %%
def invert_transformation(df_train, df_forecast):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = np.log(df_train[col].iloc[-1]) + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_var_pred_inv = invert_transformation(df1_train, df_var_pred)
df_var_pred_inv = df_var_pred_inv.filter(regex='_forecast$',axis=1)
df_var_pred_inv = np.exp(df_var_pred_inv) 

round(df_var_pred_inv.head(), 3)
# Out:
#       Real_GDP_forecast  Consumption_forecast  Investment_forecast  \
# Year
# 2010        1466029.378           1117037.543           249385.291
# 2011        1480660.823           1165940.122           258221.601
# 2012        1490072.519           1217581.620           277700.162
# 2013        1502007.082           1263063.084           305763.536
# 2014        1522453.286           1302931.816           335290.596
#
#       Employment_forecast  Oil_Prices_forecast  Public_Sector_Debt_forecast  \
# Year
# 2010            28883.455               48.763                  1128217.554
# 2011            28939.598               43.974                  1268983.443
# 2012            29036.654               44.553                  1367568.351
# 2013            29102.295               46.914                  1441626.431
# 2014            29171.408               49.706                  1505266.925
#
#       TOT_forecast  Total_Managed_Expenditure_forecast  M1_forecast  \
# Year
# 2010        98.798                          660069.078   640993.542
# 2011        99.302                          610432.092   699245.317
# 2012        98.382                          578809.702   750764.795
# 2013        97.421                          571829.759   799058.641
# 2014        96.853                          583752.358   846339.727
#
#       HousePrice_forecast
# Year
# 2010               82.410
# 2011               86.668
# 2012               93.697
# 2013              101.526
# 2014              109.498

# %% [markdown]
#  ### Evaluate the predictions

# %%
 var_mape = metrics.mean_absolute_percentage_error(df1_test, df_var_pred_inv)

var_model_accuracy = 1 - var_mape
print("The accuracy of the VAR out-of-sample prediction is:")
print("----------------------------------------------------")
print(round(var_model_accuracy, 3))
# Out:
# The accuracy of the VAR out-of-sample prediction is:
# ----------------------------------------------------
# 0.883

# %%
fig, axes = plt.subplots(nrows=int(len(df1_test.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df1_test.columns, axes.flatten())):
    df_var_pred_inv[col+'_forecast'].plot(legend=True, ax=ax, linestyle='--').autoscale(axis='x',tight=True)
    df1_test[col].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ### VECM model

# %%
# determine the order of cointegration 
var_model_levels = VAR(endog=df1_train_log)
res_var_levels = var_model_levels.select_order(maxlags=3, trend='ct')
res_var_levels.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# his time, we see that the suggested number of lags by the AIC is 2. Therefore, for both the Johansen cointegration test and for our VECM model, we will use 2–1 lags.

# %%
 def johansen_trace(y, p):
        N, l = y.shape
        joh_trace = coint_johansen(y, 0, p)
        r = 0
        for i in range(l):
            if joh_trace.lr1[i] > joh_trace.cvt[i, 1]:
                r = i + 1
        joh_trace.r = r
        return joh_trace

# %%
 for i in range(1, 2): 
    # tests for cointegration at i lags
    joh_trace = johansen_trace(df1_train_log, i)
    print('Using the Trace Test, there are', joh_trace.r, '''cointegrating vectors at 
    # %s lags between the series''' % i)
    print()
# Out:
# Using the Trace Test, there are 5 cointegrating vectors at
#    1 lags between the series

# %%
j_test = coint_johansen(df1_train_log,0,1)
print ('--------------------------------------------------')
print ('--> Trace Statistics')
print ('variable statistic Crit-90% Crit-95%  Crit-99%')
for i in range(len(j_test.lr1)):
    print ('r =', i, '\t', round(j_test.lr1[i], 4), j_test.cvt[i, 0], j_test.cvt[i, 1], j_test.cvt[i, 2])
print ('--------------------------------------------------')
print ('--> Eigen Statistics')
print ('variable statistic Crit-90% Crit-95%  Crit-99%')
for i in range(len(j_test.lr2)):
    print ('r =', i, '\t', round(j_test.lr2[i], 4), j_test.cvm[i, 0], j_test.cvm[i, 1], j_test.cvm[i, 2])
# Out:
# --------------------------------------------------
# --> Trace Statistics
# variable statistic Crit-90% Crit-95%  Crit-99%
# r = 0 	 343.8054 232.103 239.2468 253.2526
# r = 1 	 260.779 190.8714 197.3772 210.0366
# r = 2 	 190.6597 153.6341 159.529 171.0905
# r = 3 	 139.7023 120.3673 125.6185 135.9825
# r = 4 	 96.5454 91.109 95.7542 104.9637
# r = 5 	 63.2649 65.8202 69.8189 77.8202
# r = 6 	 37.8913 44.4929 47.8545 54.6815
# r = 7 	 20.371 27.0669 29.7961 35.4628
# r = 8 	 6.7543 13.4294 15.4943 19.9349
# r = 9 	 0.1192 2.7055 3.8415 6.6349
# --------------------------------------------------
# --> Eigen Statistics
# variable statistic Crit-90% Crit-95%  Crit-99%
# r = 0 	 83.0264 61.2041 64.504 71.2525
# r = 1 	 70.1193 55.2412 58.4332 64.996
# r = 2 	 50.9575 49.2855 52.3622 58.6634
# r = 3 	 43.1568 43.2947 46.2299 52.3069
# r = 4 	 33.2805 37.2786 40.0763 45.8662
# r = 5 	 25.3736 31.2379 33.8777 39.3693
# r = 6 	 17.5203 25.1236 27.5858 32.7172
# r = 7 	 13.6168 18.8928 21.1314 25.865
# r = 8 	 6.635 12.2971 14.2639 18.52
# r = 9 	 0.1192 2.7055 3.8415 6.6349

# %%
 vecm_model = VECM(endog = df1_train_log, k_ar_diff = 1, coint_rank = 5, deterministic = 'cili')
vecm_model_fit = vecm_model.fit()

# %%
vecm_model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#     Det. terms outside the coint. relation & lagged endog. parameters for equation Real_GDP
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.2827      0.172      1.643      0.100      -0.054       0.620
# L1.Consumption                  -0.0314      0.176     -0.179      0.858      -0.376       0.313
# L1.Investment                   -0.0592      0.027     -2.208      0.027      -0.112      -0.007
# L1.Employment                   -0.0745      0.213     -0.349      0.727      -0.493       0.344
# L1.Oil_Prices                   -0.0079      0.011     -0.711      0.477      -0.030       0.014
# L1.Public_Sector_Debt            0.0094      0.046      0.205      0.837      -0.080       0.099
# L1.TOT                           0.0613      0.075      0.821      0.412      -0.085       0.208
# L1.Total_Managed_Expenditure     0.0329      0.057      0.575      0.565      -0.079       0.145
# L1.M1                            0.2360      0.051      4.656      0.000       0.137       0.335
# L1.HousePrice                    0.0539      0.047      1.160      0.246      -0.037       0.145
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Consumption
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                     -0.2757      0.158     -1.740      0.082      -0.586       0.035
# L1.Consumption                   0.0341      0.162      0.211      0.833      -0.283       0.352
# L1.Investment                    0.0069      0.025      0.281      0.779      -0.041       0.055
# L1.Employment                   -0.1536      0.197     -0.781      0.435      -0.539       0.232
# L1.Oil_Prices                    0.0032      0.010      0.318      0.751      -0.017       0.023
# L1.Public_Sector_Debt           -0.1368      0.042     -3.247      0.001      -0.219      -0.054
# L1.TOT                           0.1091      0.069      1.585      0.113      -0.026       0.244
# L1.Total_Managed_Expenditure    -0.0469      0.053     -0.891      0.373      -0.150       0.056
# L1.M1                            0.1059      0.047      2.269      0.023       0.014       0.197
# L1.HousePrice                    0.0148      0.043      0.346      0.729      -0.069       0.099
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Investment
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.4545      0.849      0.536      0.592      -1.209       2.118
# L1.Consumption                   1.3040      0.868      1.502      0.133      -0.397       3.005
# L1.Investment                    0.1384      0.132      1.046      0.296      -0.121       0.398
# L1.Employment                   -1.4544      1.053     -1.381      0.167      -3.518       0.609
# L1.Oil_Prices                   -0.0278      0.055     -0.508      0.612      -0.135       0.079
# L1.Public_Sector_Debt           -0.4973      0.226     -2.204      0.028      -0.940      -0.055
# L1.TOT                          -0.4091      0.369     -1.110      0.267      -1.132       0.313
# L1.Total_Managed_Expenditure    -0.2951      0.282     -1.047      0.295      -0.848       0.257
# L1.M1                           -0.0149      0.250     -0.059      0.953      -0.505       0.475
# L1.HousePrice                    0.1263      0.229      0.551      0.582      -0.323       0.576
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Employment
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.0532      0.089      0.596      0.551      -0.122       0.228
# L1.Consumption                   0.0180      0.091      0.198      0.843      -0.161       0.197
# L1.Investment                   -0.0051      0.014     -0.365      0.715      -0.032       0.022
# L1.Employment                    0.2882      0.111      2.601      0.009       0.071       0.505
# L1.Oil_Prices                   -0.0081      0.006     -1.414      0.157      -0.019       0.003
# L1.Public_Sector_Debt            0.0376      0.024      1.586      0.113      -0.009       0.084
# L1.TOT                           0.0238      0.039      0.613      0.540      -0.052       0.100
# L1.Total_Managed_Expenditure     0.0244      0.030      0.822      0.411      -0.034       0.083
# L1.M1                            0.1224      0.026      4.652      0.000       0.071       0.174
# L1.HousePrice                    0.0352      0.024      1.460      0.144      -0.012       0.083
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Oil_Prices
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.8420      1.868      0.451      0.652      -2.819       4.503
# L1.Consumption                   2.1241      1.910      1.112      0.266      -1.620       5.868
# L1.Investment                    0.5155      0.291      1.770      0.077      -0.055       1.086
# L1.Employment                   -0.5480      2.318     -0.236      0.813      -5.091       3.995
# L1.Oil_Prices                   -0.2131      0.120     -1.769      0.077      -0.449       0.023
# L1.Public_Sector_Debt            0.4226      0.497      0.851      0.395      -0.551       1.396
# L1.TOT                          -0.7394      0.811     -0.911      0.362      -2.330       0.851
# L1.Total_Managed_Expenditure     0.5694      0.620      0.918      0.359      -0.647       1.785
# L1.M1                           -0.5013      0.550     -0.911      0.362      -1.580       0.577
# L1.HousePrice                    1.1307      0.505      2.239      0.025       0.141       2.121
# Det. terms outside the coint. relation & lagged endog. parameters for equation Public_Sector_Debt
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.0827      0.294      0.281      0.779      -0.494       0.659
# L1.Consumption                  -0.1128      0.301     -0.375      0.708      -0.702       0.477
# L1.Investment                    0.0316      0.046      0.689      0.491      -0.058       0.122
# L1.Employment                   -0.1212      0.365     -0.332      0.740      -0.837       0.594
# L1.Oil_Prices                   -0.0594      0.019     -3.132      0.002      -0.097      -0.022
# L1.Public_Sector_Debt            0.7584      0.078      9.696      0.000       0.605       0.912
# L1.TOT                          -0.1151      0.128     -0.900      0.368      -0.366       0.135
# L1.Total_Managed_Expenditure     0.0357      0.098      0.365      0.715      -0.156       0.227
# L1.M1                           -0.3056      0.087     -3.526      0.000      -0.475      -0.136
# L1.HousePrice                    0.1101      0.080      1.385      0.166      -0.046       0.266
#        Det. terms outside the coint. relation & lagged endog. parameters for equation TOT
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                     -0.0864      0.254     -0.340      0.734      -0.584       0.411
# L1.Consumption                  -0.9303      0.260     -3.582      0.000      -1.439      -0.421
# L1.Investment                    0.0489      0.040      1.236      0.217      -0.029       0.127
# L1.Employment                    0.3761      0.315      1.194      0.233      -0.241       0.994
# L1.Oil_Prices                    0.0332      0.016      2.029      0.042       0.001       0.065
# L1.Public_Sector_Debt           -0.1595      0.068     -2.362      0.018      -0.292      -0.027
# L1.TOT                           0.3395      0.110      3.077      0.002       0.123       0.556
# L1.Total_Managed_Expenditure    -0.1029      0.084     -1.220      0.222      -0.268       0.062
# L1.M1                           -0.0705      0.075     -0.942      0.346      -0.217       0.076
# L1.HousePrice                    0.0002      0.069      0.003      0.998      -0.134       0.135
# Det. terms outside the coint. relation & lagged endog. parameters for equation Total_Managed_Expenditure
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.5084      0.533      0.954      0.340      -0.536       1.553
# L1.Consumption                   0.5035      0.545      0.924      0.356      -0.565       1.572
# L1.Investment                   -0.0996      0.083     -1.199      0.231      -0.263       0.063
# L1.Employment                    0.5789      0.661      0.875      0.381      -0.717       1.875
# L1.Oil_Prices                    0.0133      0.034      0.388      0.698      -0.054       0.081
# L1.Public_Sector_Debt            0.1734      0.142      1.224      0.221      -0.104       0.451
# L1.TOT                          -0.2180      0.232     -0.942      0.346      -0.672       0.236
# L1.Total_Managed_Expenditure     0.5150      0.177      2.909      0.004       0.168       0.862
# L1.M1                           -0.0643      0.157     -0.409      0.682      -0.372       0.243
# L1.HousePrice                    0.2542      0.144      1.764      0.078      -0.028       0.537
#        Det. terms outside the coint. relation & lagged endog. parameters for equation M1
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.1917      0.326      0.589      0.556      -0.447       0.830
# L1.Consumption                  -0.1842      0.333     -0.553      0.580      -0.837       0.469
# L1.Investment                    0.0206      0.051      0.406      0.685      -0.079       0.120
# L1.Employment                    0.9442      0.404      2.337      0.019       0.152       1.736
# L1.Oil_Prices                   -0.0070      0.021     -0.332      0.740      -0.048       0.034
# L1.Public_Sector_Debt           -0.0486      0.087     -0.562      0.574      -0.218       0.121
# L1.TOT                           0.0094      0.141      0.067      0.947      -0.268       0.287
# L1.Total_Managed_Expenditure    -0.0183      0.108     -0.169      0.866      -0.230       0.194
# L1.M1                            0.3479      0.096      3.625      0.000       0.160       0.536
# L1.HousePrice                   -0.0250      0.088     -0.284      0.776      -0.198       0.148
#    Det. terms outside the coint. relation & lagged endog. parameters for equation HousePrice
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                     -0.3029      0.389     -0.778      0.436      -1.066       0.460
# L1.Consumption                   0.7083      0.398      1.780      0.075      -0.072       1.488
# L1.Investment                    0.0810      0.061      1.334      0.182      -0.038       0.200
# L1.Employment                   -0.5698      0.483     -1.180      0.238      -1.516       0.377
# L1.Oil_Prices                   -0.0092      0.025     -0.368      0.713      -0.058       0.040
# L1.Public_Sector_Debt           -0.1106      0.103     -1.069      0.285      -0.313       0.092
# L1.TOT                           0.1557      0.169      0.921      0.357      -0.176       0.487
# L1.Total_Managed_Expenditure     0.2333      0.129      1.804      0.071      -0.020       0.487
# L1.M1                            0.4603      0.115      4.014      0.000       0.236       0.685
# L1.HousePrice                    0.4985      0.105      4.738      0.000       0.292       0.705
#               Loading coefficients (alpha) for equation Real_GDP
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.5230      0.142     -3.684      0.000      -0.801      -0.245
# ec2            0.2413      0.123      1.954      0.051      -0.001       0.483
# ec3            0.0683      0.020      3.479      0.001       0.030       0.107
# ec4            0.2136      0.155      1.381      0.167      -0.090       0.517
# ec5           -0.0122      0.006     -1.902      0.057      -0.025       0.000
#             Loading coefficients (alpha) for equation Consumption
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.5045      0.131      3.858      0.000       0.248       0.761
# ec2           -0.4334      0.114     -3.811      0.000      -0.656      -0.210
# ec3           -0.0118      0.018     -0.653      0.514      -0.047       0.024
# ec4           -0.7486      0.142     -5.255      0.000      -1.028      -0.469
# ec5            0.0049      0.006      0.828      0.407      -0.007       0.016
#              Loading coefficients (alpha) for equation Investment
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -1.8556      0.700     -2.649      0.008      -3.228      -0.483
# ec2            1.9631      0.609      3.222      0.001       0.769       3.157
# ec3           -0.3098      0.097     -3.201      0.001      -0.499      -0.120
# ec4            0.6045      0.763      0.792      0.428      -0.891       2.100
# ec5           -0.0228      0.032     -0.719      0.472      -0.085       0.039
#              Loading coefficients (alpha) for equation Employment
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0216      0.074     -0.293      0.770      -0.166       0.123
# ec2           -0.0386      0.064     -0.602      0.547      -0.164       0.087
# ec3            0.0257      0.010      2.524      0.012       0.006       0.046
# ec4           -0.1260      0.080     -1.570      0.116      -0.283       0.031
# ec5            0.0017      0.003      0.512      0.609      -0.005       0.008
#              Loading coefficients (alpha) for equation Oil_Prices
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.7262      1.542      0.471      0.638      -2.295       3.748
# ec2           -0.0067      1.341     -0.005      0.996      -2.635       2.621
# ec3           -0.1950      0.213     -0.915      0.360      -0.612       0.223
# ec4           -0.1523      1.679     -0.091      0.928      -3.444       3.139
# ec5            0.0686      0.070      0.984      0.325      -0.068       0.205
#          Loading coefficients (alpha) for equation Public_Sector_Debt
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.3915      0.243      1.613      0.107      -0.084       0.867
# ec2           -0.3785      0.211     -1.792      0.073      -0.792       0.035
# ec3           -0.0887      0.034     -2.644      0.008      -0.154      -0.023
# ec4           -0.3365      0.264     -1.272      0.203      -0.855       0.182
# ec5            0.0706      0.011      6.424      0.000       0.049       0.092
#                 Loading coefficients (alpha) for equation TOT
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.1803      0.210      0.860      0.390      -0.230       0.591
# ec2           -0.1120      0.182     -0.614      0.539      -0.469       0.245
# ec3           -0.0670      0.029     -2.312      0.021      -0.124      -0.010
# ec4           -0.5130      0.228     -2.247      0.025      -0.960      -0.065
# ec5            0.0092      0.009      0.967      0.333      -0.009       0.028
#      Loading coefficients (alpha) for equation Total_Managed_Expenditure
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -1.2093      0.440     -2.750      0.006      -2.071      -0.347
# ec2            0.7057      0.383      1.845      0.065      -0.044       1.455
# ec3            0.0432      0.061      0.711      0.477      -0.076       0.162
# ec4            0.9666      0.479      2.017      0.044       0.028       1.906
# ec5            0.0177      0.020      0.888      0.374      -0.021       0.057
#                  Loading coefficients (alpha) for equation M1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.6754      0.269     -2.513      0.012      -1.202      -0.149
# ec2            0.7605      0.234      3.253      0.001       0.302       1.219
# ec3           -0.1164      0.037     -3.134      0.002      -0.189      -0.044
# ec4            0.6084      0.293      2.078      0.038       0.034       1.182
# ec5           -0.0284      0.012     -2.337      0.019      -0.052      -0.005
#              Loading coefficients (alpha) for equation HousePrice
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.6858      0.321      2.135      0.033       0.056       1.315
# ec2           -0.3644      0.279     -1.304      0.192      -0.912       0.183
# ec3           -0.0602      0.044     -1.357      0.175      -0.147       0.027
# ec4           -1.0493      0.350     -2.999      0.003      -1.735      -0.364
# ec5            0.0043      0.015      0.298      0.766      -0.024       0.033
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2     -3.061e-16          0          0      0.000   -3.06e-16   -3.06e-16
# beta.3      6.384e-18          0          0      0.000    6.38e-18    6.38e-18
# beta.4      3.122e-16          0          0      0.000    3.12e-16    3.12e-16
# beta.5     -1.502e-18          0          0      0.000    -1.5e-18    -1.5e-18
# beta.6         0.1800      0.085      2.117      0.034       0.013       0.347
# beta.7         0.2401      0.138      1.741      0.082      -0.030       0.510
# beta.8        -0.2359      0.328     -0.719      0.472      -0.879       0.407
# beta.9         0.0854      0.036      2.382      0.017       0.015       0.156
# beta.10        0.0173      0.761      0.023      0.982      -1.475       1.509
# const        -13.8603      0.213    -65.056      0.000     -14.278     -13.443
# lin_trend     -0.0260      0.345     -0.075      0.940      -0.703       0.651
#           Cointegration relations for loading-coefficients-column 2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1      2.382e-16          0          0      0.000    2.38e-16    2.38e-16
# beta.2         1.0000          0          0      0.000       1.000       1.000
# beta.3     -1.627e-17          0          0      0.000   -1.63e-17   -1.63e-17
# beta.4      -1.74e-16          0          0      0.000   -1.74e-16   -1.74e-16
# beta.5      1.968e-17          0          0      0.000    1.97e-17    1.97e-17
# beta.6         0.1636      0.822      0.199      0.842      -1.448       1.775
# beta.7        -0.3956      0.090     -4.406      0.000      -0.572      -0.220
# beta.8        -0.1426      1.907     -0.075      0.940      -3.881       3.595
# beta.9         0.2360      0.069      3.443      0.001       0.102       0.370
# beta.10       -0.3262      0.111     -2.936      0.003      -0.544      -0.108
# const        -12.9339      0.264    -48.904      0.000     -13.452     -12.416
# lin_trend     -0.0189      0.029     -0.655      0.512      -0.076       0.038
#           Cointegration relations for loading-coefficients-column 3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1     -4.883e-16          0          0      0.000   -4.88e-16   -4.88e-16
# beta.2     -1.156e-15          0          0      0.000   -1.16e-15   -1.16e-15
# beta.3         1.0000          0          0      0.000       1.000       1.000
# beta.4     -4.498e-16          0          0      0.000    -4.5e-16    -4.5e-16
# beta.5      3.555e-17          0          0      0.000    3.56e-17    3.56e-17
# beta.6         0.6581      0.613      1.073      0.283      -0.544       1.861
# beta.7         0.6908      0.068     10.136      0.000       0.557       0.824
# beta.8        -0.9346      0.111     -8.457      0.000      -1.151      -0.718
# beta.9         1.2723      0.263      4.837      0.000       0.757       1.788
# beta.10       -0.4984      0.029    -17.349      0.000      -0.555      -0.442
# const        -22.1104      0.610    -36.239      0.000     -23.306     -20.915
# lin_trend     -0.0667      0.057     -1.179      0.238      -0.177       0.044
#           Cointegration relations for loading-coefficients-column 4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1     -4.103e-17          0          0      0.000    -4.1e-17    -4.1e-17
# beta.2      1.849e-16          0          0      0.000    1.85e-16    1.85e-16
# beta.3      -1.01e-16          0          0      0.000   -1.01e-16   -1.01e-16
# beta.4         1.0000          0          0      0.000       1.000       1.000
# beta.5      8.836e-18          0          0      0.000    8.84e-18    8.84e-18
# beta.6        -0.0331      0.092     -0.361      0.718      -0.213       0.147
# beta.7         0.4109      0.218      1.883      0.060      -0.017       0.839
# beta.8         0.0691      0.024      2.900      0.004       0.022       0.116
# beta.9        -0.1683      0.506     -0.333      0.739      -1.160       0.824
# beta.10        0.2367      1.193      0.199      0.843      -2.101       2.574
# const        -10.2740      1.934     -5.313      0.000     -14.064      -6.484
# lin_trend     -0.0134      4.603     -0.003      0.998      -9.034       9.007
#           Cointegration relations for loading-coefficients-column 5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1     -8.771e-17          0          0      0.000   -8.77e-17   -8.77e-17
# beta.2      1.653e-16          0          0      0.000    1.65e-16    1.65e-16
# beta.3     -5.161e-16          0          0      0.000   -5.16e-16   -5.16e-16
# beta.4       1.29e-15          0          0      0.000    1.29e-15    1.29e-15
# beta.5         1.0000          0          0      0.000       1.000       1.000
# beta.6        -3.3995      0.503     -6.763      0.000      -4.385      -2.414
# beta.7        -2.1472     10.676     -0.201      0.841     -23.071      18.777
# beta.8        -2.0498      0.004   -574.126      0.000      -2.057      -2.043
# beta.9         3.7538      0.006    648.448      0.000       3.742       3.765
# beta.10       -1.3849      0.014   -100.507      0.000      -1.412      -1.358
# const         23.4097      0.002   1.56e+04      0.000      23.407      23.413
# lin_trend      0.1192      0.032      3.730      0.000       0.057       0.182
# ==============================================================================
# """

# %%
dw_check_vecm = durbin_watson(vecm_model_fit.resid)

for col, val in zip(df1_train_log_diff.columns, dw_check_vecm):
    print("Durbin-Watson statistic for:")
    print(col, '-->', round(val, 2))
    print("----------------------------")
# Out:
# Durbin-Watson statistic for:
# Real_GDP --> 1.93
# ----------------------------
# Durbin-Watson statistic for:
# Consumption --> 2.04
# ----------------------------
# Durbin-Watson statistic for:
# Investment --> 1.95
# ----------------------------
# Durbin-Watson statistic for:
# Employment --> 2.12
# ----------------------------
# Durbin-Watson statistic for:
# Oil_Prices --> 1.93
# ----------------------------
# Durbin-Watson statistic for:
# Public_Sector_Debt --> 2.14
# ----------------------------
# Durbin-Watson statistic for:
# TOT --> 1.91
# ----------------------------
# Durbin-Watson statistic for:
# Total_Managed_Expenditure --> 1.88
# ----------------------------
# Durbin-Watson statistic for:
# M1 --> 1.96
# ----------------------------
# Durbin-Watson statistic for:
# HousePrice --> 2.17
# ----------------------------

# %%
vecm_pred = vecm_model_fit.predict(steps=len(df1_test))

# %%
df_vecm_pred = pd.DataFrame(vecm_pred, 
                        index=df1_test.index, 
                        columns=df1_train.columns + '_forecast')

# %%
df_vecm_pred_inv = np.exp(df_vecm_pred)  
df_vecm_pred_inv
# Out:
#       Real_GDP_forecast  Consumption_forecast  Investment_forecast  \
# Year
# 2010       1.502387e+06          1.125311e+06        226928.439350
# 2011       1.551272e+06          1.167408e+06        240123.401852
# 2012       1.594365e+06          1.239381e+06        265847.939587
# 2013       1.634310e+06          1.322467e+06        304325.111080
# 2014       1.671047e+06          1.392081e+06        352685.079153
# 2015       1.708042e+06          1.436730e+06        397724.052258
# 2016       1.748612e+06          1.455657e+06        425275.039723
#
#       Employment_forecast  Oil_Prices_forecast  Public_Sector_Debt_forecast  \
# Year
# 2010         29249.831402            47.089775                 1.107118e+06
# 2011         29584.760291            41.901048                 1.185010e+06
# 2012         30080.170384            41.351862                 1.170066e+06
# 2013         30585.845138            44.815115                 1.098468e+06
# 2014         30973.302245            52.475769                 1.020095e+06
# 2015         31221.665788            62.462557                 9.701163e+05
# 2016         31369.342391            72.055080                 9.661662e+05
#
#       TOT_forecast  Total_Managed_Expenditure_forecast    M1_forecast  \
# Year
# 2010     98.267665                       671809.884373  618410.430174
# 2011     98.328780                       646203.239262  679293.705469
# 2012     99.496136                       608803.671734  742173.300140
# 2013     99.953684                       584449.957962  798335.006906
# 2014     99.411702                       589944.124257  847191.967395
# 2015     98.658837                       629994.016931  889011.570055
# 2016     98.114496                       704558.259746  926269.667869
#
#       HousePrice_forecast
# Year
# 2010            82.294270
# 2011            85.784206
# 2012            96.439124
# 2013           113.048539
# 2014           132.238278
# 2015           149.748397
# 2016           162.011821

# %% [markdown]
# ### Evaluate the predictions

# %%
vecm_mape = metrics.mean_absolute_percentage_error(df1_test, df_vecm_pred_inv)
vecm_model_accuracy = 1 - vecm_mape

print("The accuracy of the VECM out-of-sample prediction is:")
print("----------------------------------------------------")
print(round(vecm_model_accuracy, 3))
# Out:
# The accuracy of the VECM out-of-sample prediction is:
# ----------------------------------------------------
# 0.836

# %%
 fig, axes = plt.subplots(nrows=int(len(df1_test.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df1_test.columns, axes.flatten())):
    df_vecm_pred_inv[col+'_forecast'].plot(legend=True, ax=ax, linestyle="--").autoscale(axis='x',tight=True)
    df1_test[col].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ###  VARMA model

# %%
param_grid = {'p': [1,2,3], 'q':[1,2,3], 'tr': ['n','c','t','ct']}
pg = list(ParameterGrid(param_grid))

#tr': This parameter represents the trend type. It can take four values: 'n' for no trend, 'c' for a constant trend, 
#'t' for a linear trend, and 'ct' for a constant with a linear trend.

# %%
# Assuming df1_train_log_diff and pg are defined earlier in your code

# Initialize an empty list to store dictionaries
results = []

for b in pg:
    p = b.get('p')
    q = b.get('q')
    tr = b.get('tr')
    model = VARMAX(df1_train_log_diff, order=(p, q), trend=tr, initialization='approximate_diffuse').fit(maxiter=30)
    aic = model.aic

    # Append a dictionary to the list
    results.append({'p': p, 'q': q, 'tr': tr, 'AIC': aic})

# Convert the list of dictionaries to a DataFrame

# %%
df_fitted_VARMA = pd.DataFrame(results)

# %%
 df_fitted_VARMA = pd.DataFrame(columns=['p', 
                                         'q', 
                                         'tr',
                                         'AIC'])

for a,b in enumerate(pg):
    p = b.get('p')
    q = b.get('q')
    tr = b.get('tr')
    model = VARMAX(df1_train_log_diff, order=(p,q), trend=tr, initialization='approximate_diffuse').fit(maxiter=30)
    aic = model.aic

    
    df_fitted_VARMA = df_fitted_VARMA.append({'p': p, 'q': q, 'tr': tr, 'AIC':aic}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1096\875358608.py in ?()
#       9    tr = b.get('tr')
#      10    model = VARMAX(df1_train_log_diff, order=(p,q), trend=tr, initialization='approximate_diffuse').fit(maxiter=30)
#      11    aic = model.aic
#      12
# ---> 13    df_fitted_VARMA = df_fitted_VARMA.append({'p': p, 'q': q, 'tr': tr, 'AIC':aic}, ignore_index=True)
#
# ~\anaconda3\envs\final_project\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
