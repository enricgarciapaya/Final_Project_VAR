# %%
# Proyecto final Bueno

# %%
#0 Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-bright')

from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.stats.stattools import durbin_watson
from statsmodels.tsa.api import VAR
from statsmodels.tsa.api import VECM
from statsmodels.tsa.vector_ar.vecm import select_coint_rank
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.statespace.varmax import VARMAX
from sklearn import metrics
from sklearn.model_selection import ParameterGrid
import scipy

import warnings
warnings.filterwarnings('ignore')

# %%
#1. Import-transformation of the variable

# %%
UK = pd.read_csv("millenniumofdata_v3_headlines.csv", skiprows=[1])

# %%
display(UK)
# Out:
#      Description  Real GDP of England at market prices  \
# 0           2016                             1672084.0
# 1           2015                             1642802.0
# 2           2014                             1604169.0
# 3           2013                             1551553.0
# 4           2012                             1530435.0
# ..           ...                                   ...
# 803         1213                                   NaN
# 804         1212                                   NaN
# 805         1211                                   NaN
# 806         1210                                   NaN
# 807         1209                                   NaN
#
#      Real GDP of England at factor cost   \
# 0                              1413759.0
# 1                              1388074.0
# 2                              1352028.0
# 3                              1302596.0
# 4                              1282939.0
# ..                                   ...
# 803                                  NaN
# 804                                  NaN
# 805                                  NaN
# 806                                  NaN
# 807                                  NaN
#
#      Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0                                            1865410.0
# 1                                            1832318.0
# 2                                            1792976.0
# 3                                            1739563.0
# 4                                            1706942.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders  \
# 0                                            1648678.0
# 1                                            1618725.0
# 2                                            1580198.0
# 3                                            1527959.0
# 4                                            1505417.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Index of real UK GDP at factor cost - based on changing political boundaries,   \
# 0                                             872.4447
# 1                                             856.5943
# 2                                             836.2066
# 3                                             808.5629
# 4                                             796.6341
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Composite estimate of English and (geographically-consistent) UK real GDP at factor cost  \
# 0                                             107.9007
# 1                                             105.9403
# 2                                             103.4189
# 3                                             100.0000
# 4                                              98.5247
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      HP-filter of log of real composite estimate of English and UK real GDP at factor cost  \
# 0                                                 1.55
# 1                                                 1.09
# 2                                                 0.04
# 3                                                -2.01
# 4                                                -2.25
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real UK gross disposable national income at market prices, constant border estimate  \
# 0                                            1843502.0
# 1                                            1793997.0
# 2                                            1749880.0
# 3                                            1702359.0
# 4                                            1681556.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Real consumption  ...  UK Public sector debt.1  UK Public sector debt.2  \
# 0           1223627.0  ...                     87.7                     87.7
# 1           1190789.0  ...                     86.0                     86.0
# 2           1163136.0  ...                     85.4                     85.4
# 3           1138546.0  ...                     83.6                     83.6
# 4           1121061.0  ...                     80.6                     80.6
# ..                ...  ...                      ...                      ...
# 803               NaN  ...                      NaN                      NaN
# 804               NaN  ...                      NaN                      NaN
# 805               NaN  ...                      NaN                      NaN
# 806               NaN  ...                      NaN                      NaN
# 807               NaN  ...                      NaN                      NaN
#
#      Central Government Gross Debt  Central Government Gross Debt.1  \
# 0                        1628685.0                        2070854.0
# 1                        1581986.0                        2005548.0
# 2                        1502068.0                        1736853.0
# 3                        1404319.0                        1731089.0
# 4                        1329598.0                        1569916.0
# ..                             ...                              ...
# 803                            NaN                              NaN
# 804                            NaN                              NaN
# 805                            NaN                              NaN
# 806                            NaN                              NaN
# 807                            NaN                              NaN
#
#      Trade deficit  Trade deficit.1  Current account   Current account .1  \
# 0         -37026.0            -1.91          -84504.0                -4.4
# 1         -29788.0            -1.59          -80233.0                -4.3
# 2         -36223.0            -1.99          -84998.0                -4.7
# 3         -39238.0            -2.26          -76442.0                -4.4
# 4         -37334.0            -2.23          -61433.0                -3.7
# ..             ...              ...               ...                 ...
# 803            NaN              NaN               NaN                 NaN
# 804            NaN              NaN               NaN                 NaN
# 805            NaN              NaN               NaN                 NaN
# 806            NaN              NaN               NaN                 NaN
# 807            NaN              NaN               NaN                 NaN
#
#      Current account deficit including estimated non-monetary bullion flows  \
# 0                                             -84504.0
# 1                                             -80233.0
# 2                                             -84998.0
# 3                                             -76442.0
# 4                                             -61433.0
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
#      Current account deficit including estimated non-monetary bullion flows.1
# 0                                                 -4.4
# 1                                                 -4.3
# 2                                                 -4.7
# 3                                                 -4.4
# 4                                                 -3.7
# ..                                                 ...
# 803                                                NaN
# 804                                                NaN
# 805                                                NaN
# 806                                                NaN
# 807                                                NaN
#
# [808 rows x 77 columns]

# %%
df=UK.copy()

# %%
df.head()
# Out:
#    Description  Real GDP of England at market prices  \
# 0         2016                             1672084.0
# 1         2015                             1642802.0
# 2         2014                             1604169.0
# 3         2013                             1551553.0
# 4         2012                             1530435.0
#
#    Real GDP of England at factor cost   \
# 0                            1413759.0
# 1                            1388074.0
# 2                            1352028.0
# 3                            1302596.0
# 4                            1282939.0
#
#    Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0                                          1865410.0
# 1                                          1832318.0
# 2                                          1792976.0
# 3                                          1739563.0
# 4                                          1706942.0
#
#    Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders  \
# 0                                          1648678.0
# 1                                          1618725.0
# 2                                          1580198.0
# 3                                          1527959.0
# 4                                          1505417.0
#
#    Index of real UK GDP at factor cost - based on changing political boundaries,   \
# 0                                           872.4447
# 1                                           856.5943
# 2                                           836.2066
# 3                                           808.5629
# 4                                           796.6341
#
#    Composite estimate of English and (geographically-consistent) UK real GDP at factor cost  \
# 0                                           107.9007
# 1                                           105.9403
# 2                                           103.4189
# 3                                           100.0000
# 4                                            98.5247
#
#    HP-filter of log of real composite estimate of English and UK real GDP at factor cost  \
# 0                                               1.55
# 1                                               1.09
# 2                                               0.04
# 3                                              -2.01
# 4                                              -2.25
#
#    Real UK gross disposable national income at market prices, constant border estimate  \
# 0                                          1843502.0
# 1                                          1793997.0
# 2                                          1749880.0
# 3                                          1702359.0
# 4                                          1681556.0
#
#    Real consumption  ...  UK Public sector debt.1  UK Public sector debt.2  \
# 0         1223627.0  ...                     87.7                     87.7
# 1         1190789.0  ...                     86.0                     86.0
# 2         1163136.0  ...                     85.4                     85.4
# 3         1138546.0  ...                     83.6                     83.6
# 4         1121061.0  ...                     80.6                     80.6
#
#    Central Government Gross Debt  Central Government Gross Debt.1  \
# 0                      1628685.0                        2070854.0
# 1                      1581986.0                        2005548.0
# 2                      1502068.0                        1736853.0
# 3                      1404319.0                        1731089.0
# 4                      1329598.0                        1569916.0
#
#    Trade deficit  Trade deficit.1  Current account   Current account .1  \
# 0       -37026.0            -1.91          -84504.0                -4.4
# 1       -29788.0            -1.59          -80233.0                -4.3
# 2       -36223.0            -1.99          -84998.0                -4.7
# 3       -39238.0            -2.26          -76442.0                -4.4
# 4       -37334.0            -2.23          -61433.0                -3.7
#
#    Current account deficit including estimated non-monetary bullion flows  \
# 0                                           -84504.0
# 1                                           -80233.0
# 2                                           -84998.0
# 3                                           -76442.0
# 4                                           -61433.0
#
#    Current account deficit including estimated non-monetary bullion flows.1
# 0                                               -4.4
# 1                                               -4.3
# 2                                               -4.7
# 3                                               -4.4
# 4                                               -3.7
#
# [5 rows x 77 columns]

# %%
#1.1 Variables we are going to use

# %%
#"Real GDP of England at market prices"
#Real consumption
#Real investment
#Employment
#$ Oil prices
#UK Public sector debt
#Trade deficit
#Public sector Total Managed Expenditure
#M1
#Capital Services, whole economy

# %%
#1.2 Creating de DF
df1 = df[["Description", "Real GDP of England at market prices", "Real consumption", "Real investment",
            "Employment", "$ Oil prices", "UK Public sector debt", "Terms of Trade",
            "Public sector Total Managed Expenditure", "M1", "Capital Services, whole economy"]]

# %%
df1.head()
# Out:
#    Description  Real GDP of England at market prices  Real consumption  \
# 0         2016                             1672084.0         1223627.0
# 1         2015                             1642802.0         1190789.0
# 2         2014                             1604169.0         1163136.0
# 3         2013                             1551553.0         1138546.0
# 4         2012                             1530435.0         1121061.0
#
#    Real investment  Employment  $ Oil prices  UK Public sector debt  \
# 0         310816.0     31741.0         43.82              1701800.0
# 1         309144.0     31296.0         52.39              1610500.0
# 2         298872.0     30757.0         98.93              1556000.0
# 3         280224.0     30044.0        108.66              1454000.0
# 4         271534.0     29696.0        111.67              1349700.0
#
#    Terms of Trade  Public sector Total Managed Expenditure        M1  \
# 0          102.31                                 766473.0  802754.0
# 1          102.27                                 752904.0  780106.0
# 2          101.54                                 751173.0  734574.0
# 3          100.00                                 730662.0  683952.0
# 4           97.81                                 735765.0  617849.0
#
#    Capital Services, whole economy
# 0                         294233.0
# 1                         287407.0
# 2                         280218.0
# 3                         274195.0
# 4                         268886.0

# %%
#1.4 Change the name of columns
df1.rename(columns={
    "Description": "Year",
    "Real GDP of England at market prices": "Real_GDP",
    "Real consumption": "Consumption",
    "Real investment": "Investment",
    "Employment": "Employment",
    "$ Oil prices": "Oil_Prices",
    "UK Public sector debt": "Public_Sector_Debt",
    "Terms of Trade": "TOT",
    "Public sector Total Managed Expenditure": "Total_Managed_Expenditure",
    "M1": "M1",
    "Capital Services, whole economy": "Capital"
}, inplace=True)

# %%
df1.head()
# Out:
#    Year   Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# 0  2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 1  2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2  2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 3  2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 4  2012  1530435.0    1121061.0    271534.0     29696.0      111.67
#
#    Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1   Capital
# 0           1701800.0  102.31                   766473.0  802754.0  294233.0
# 1           1610500.0  102.27                   752904.0  780106.0  287407.0
# 2           1556000.0  101.54                   751173.0  734574.0  280218.0
# 3           1454000.0  100.00                   730662.0  683952.0  274195.0
# 4           1349700.0   97.81                   735765.0  617849.0  268886.0

# %%
#1.5Display the DataFrame with the "Year" column as the index
df1.set_index("Year",inplace=True)

# %%
display(df1)
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# ...         ...          ...         ...         ...         ...
# 1213        NaN          NaN         NaN         NaN         NaN
# 1212        NaN          NaN         NaN         NaN         NaN
# 1211        NaN          NaN         NaN         NaN         NaN
# 1210        NaN          NaN         NaN         NaN         NaN
# 1209        NaN          NaN         NaN         NaN         NaN
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2016           1701800.0  102.31                   766473.0  802754.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# ...                  ...     ...                        ...       ...
# 1213                 NaN     NaN                        NaN       NaN
# 1212                 NaN     NaN                        NaN       NaN
# 1211                 NaN     NaN                        NaN       NaN
# 1210                 NaN     NaN                        NaN       NaN
# 1209                 NaN     NaN                        NaN       NaN
#
#        Capital
# Year
# 2016  294233.0
# 2015  287407.0
# 2014  280218.0
# 2013  274195.0
# 2012  268886.0
# ...        ...
# 1213       NaN
# 1212       NaN
# 1211       NaN
# 1210       NaN
# 1209       NaN
#
# [808 rows x 10 columns]

# %%
# Null Values, we do not need 
df1.isna().sum()
# Out:
# Real_GDP                      61
# Consumption                  621
# Investment                   621
# Employment                   646
# Oil_Prices                   652
# Public_Sector_Debt           482
# TOT                          563
# Total_Managed_Expenditure    691
# M1                           713
# Capital                      551
# dtype: int64

# %%
df1.dropna(axis=0, inplace=True)

# %%
df1 # We end up with a database with 95 years
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# ...         ...          ...         ...         ...         ...
# 1926   191950.0     156780.0     16743.0     18537.0        1.88
# 1925   198406.0     155908.0     17250.0     18532.0        1.68
# 1924   191378.0     153246.0     15141.0     18322.0        1.43
# 1923   182423.0     148335.0     12990.0     18051.0        1.34
# 1922   176904.0     143929.0     12653.0     17821.0        1.61
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2016           1701800.0  102.31                   766473.0  802754.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# ...                  ...     ...                        ...       ...
# 1926              7648.0   92.39                     1155.0    1476.0
# 1925              7642.0   88.37                     1096.0    1491.0
# 1924              7676.0   91.05                     1041.0    1519.0
# 1923              7734.0   94.44                     1048.0    1537.0
# 1922              7790.0   97.57                     1172.0    1563.0
#
#        Capital
# Year
# 2016  294233.0
# 2015  287407.0
# 2014  280218.0
# 2013  274195.0
# 2012  268886.0
# ...        ...
# 1926   19977.0
# 1925   19944.0
# 1924   19782.0
# 1923   19684.0
# 1922   19619.0
#
# [95 rows x 10 columns]

# %%
df1.describe()
# Out:
#            Real_GDP   Consumption     Investment    Employment  Oil_Prices  \
# count  9.500000e+01  9.500000e+01      95.000000     95.000000   95.000000
# mean   7.104196e+05  4.907425e+05  132098.778947  24539.884211   18.111053
# std    4.583850e+05  3.384436e+05  100501.882425   3208.878998   27.096773
# min    1.769040e+05  1.439290e+05    7170.000000  17821.000000    0.650000
# 25%    3.146170e+05  2.010925e+05   24271.500000  23398.500000    1.695000
# 50%    5.969050e+05  3.627140e+05  138923.000000  24725.000000    2.080000
# 75%    1.020780e+06  6.941740e+05  222956.500000  26065.000000   24.085000
# max    1.672084e+06  1.223627e+06  312995.000000  31741.000000  111.670000
#
#        Public_Sector_Debt         TOT  Total_Managed_Expenditure  \
# count        9.500000e+01   95.000000                  95.000000
# mean         2.199856e+05   95.531895              165642.757895
# std          3.879074e+05    5.991166              234999.419001
# min          7.586000e+03   78.520000                1041.000000
# 25%          2.436850e+04   91.780000                4925.500000
# 50%          3.364200e+04   95.690000               20233.000000
# 75%          2.138755e+05   99.040000              283823.500000
# max          1.701800e+06  107.170000              766473.000000
#
#                   M1        Capital
# count      95.000000      95.000000
# mean   125693.768421   92429.273684
# std    210737.941426   83550.382373
# min      1383.000000   19619.000000
# 25%      5397.500000   22265.500000
# 50%      9098.000000   58760.000000
# 75%    147491.500000  135358.500000
# max    802754.000000  294233.000000

# %%
df1 = df1.apply(pd.to_numeric, errors='coerce')

# Now, run describe() again
print(df1.describe())
# Out:
#            Real_GDP   Consumption     Investment    Employment  Oil_Prices  \
# count  9.500000e+01  9.500000e+01      95.000000     95.000000   95.000000
# mean   7.104196e+05  4.907425e+05  132098.778947  24539.884211   18.111053
# std    4.583850e+05  3.384436e+05  100501.882425   3208.878998   27.096773
# min    1.769040e+05  1.439290e+05    7170.000000  17821.000000    0.650000
# 25%    3.146170e+05  2.010925e+05   24271.500000  23398.500000    1.695000
# 50%    5.969050e+05  3.627140e+05  138923.000000  24725.000000    2.080000
# 75%    1.020780e+06  6.941740e+05  222956.500000  26065.000000   24.085000
# max    1.672084e+06  1.223627e+06  312995.000000  31741.000000  111.670000
#
#        Public_Sector_Debt         TOT  Total_Managed_Expenditure  \
# count        9.500000e+01   95.000000                  95.000000
# mean         2.199856e+05   95.531895              165642.757895
# std          3.879074e+05    5.991166              234999.419001
# min          7.586000e+03   78.520000                1041.000000
# 25%          2.436850e+04   91.780000                4925.500000
# 50%          3.364200e+04   95.690000               20233.000000
# 75%          2.138755e+05   99.040000              283823.500000
# max          1.701800e+06  107.170000              766473.000000
#
#                   M1        Capital
# count      95.000000      95.000000
# mean   125693.768421   92429.273684
# std    210737.941426   83550.382373
# min      1383.000000   19619.000000
# 25%      5397.500000   22265.500000
# 50%      9098.000000   58760.000000
# 75%    147491.500000  135358.500000
# max    802754.000000  294233.000000

# %%
#  Now we have a 10-variable data set with a total of 95 year observations starting on 1922

# %%
 fig, axes = plt.subplots(nrows=5, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1[df1.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title(df1.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# We can see that none of the series is stationary, all of them shows a Trend,
# All the varibles got volatile after the 2ww

# %%
### Seasonal decompose

# %%
df1_reverse = df1[::-1]
df1=df1_reverse

# %%
df1=df1_reverse

# %%
for i, ax in enumerate(axes.flatten()):
    data = seasonal_decompose(df1[df1.columns[i]], model= 'additive',period=1,)
    ax = data.plot()
    
plt.tight_layout();

# %%
##ACF

# %%
for i in df1:
    sgt.plot_acf(df1[i],lags=30, zero=False)
    plt.title("ACF for %s"%i)
    plt.show()
# Why we use ACF and what can we infer from below

# %%
for i in df1:
    sgt.plot_pacf(df1[i],lags=15, zero=False)
    plt.title("PACF for %s"%i)
    plt.show()
# Why we use ACF and what can we infer from below

# %%
def adf_test(timeseries, name):
    dftest = sts.adfuller(timeseries)
    dfoutput = pd.Series(dftest[0:4], 
                         index=['Test Statistic','p-value','Lags Used','Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print('\033[1m{:10s}\033[0m'.format(name))
    print(dfoutput)
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=4).mean()
    rolstd = timeseries.rolling(window=4).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.grid()
    plt.show(block=False)

# %%
for i in df1:
    adf_test(df1[i], i)
# Out:
# Real_GDP
# Test Statistic           2.693625
# p-value                  0.999087
# Lags Used                2.000000
# Observations Used       92.000000
# Critical Value (1%)     -3.503515
# Critical Value (5%)     -2.893508
# Critical Value (10%)    -2.583824
# dtype: float64
# Consumption
# Test Statistic           2.051147
# p-value                  0.998736
# Lags Used                1.000000
# Observations Used       93.000000
# Critical Value (1%)     -3.502705
# Critical Value (5%)     -2.893158
# Critical Value (10%)    -2.583637
# dtype: float64
# Investment
# Test Statistic           0.466425
# p-value                  0.983816
# Lags Used                2.000000
# Observations Used       92.000000
# Critical Value (1%)     -3.503515
# Critical Value (5%)     -2.893508
# Critical Value (10%)    -2.583824
# dtype: float64
# Employment
# Test Statistic          -0.724370
# p-value                  0.840336
# Lags Used                1.000000
# Observations Used       93.000000
# Critical Value (1%)     -3.502705
# Critical Value (5%)     -2.893158
# Critical Value (10%)    -2.583637
# dtype: float64
# Oil_Prices
# Test Statistic          -1.107090
# p-value                  0.712236
# Lags Used                9.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# Public_Sector_Debt
# Test Statistic           5.491482
# p-value                  1.000000
# Lags Used               10.000000
# Observations Used       84.000000
# Critical Value (1%)     -3.510712
# Critical Value (5%)     -2.896616
# Critical Value (10%)    -2.585482
# dtype: float64
# TOT
# Test Statistic          -2.859945
# p-value                  0.050208
# Lags Used                3.000000
# Observations Used       91.000000
# Critical Value (1%)     -3.504343
# Critical Value (5%)     -2.893866
# Critical Value (10%)    -2.584015
# dtype: float64
# Total_Managed_Expenditure
# Test Statistic           1.305582
# p-value                  0.996640
# Lags Used                3.000000
# Observations Used       91.000000
# Critical Value (1%)     -3.504343
# Critical Value (5%)     -2.893866
# Critical Value (10%)    -2.584015
# dtype: float64
# M1
# Test Statistic           0.831598
# p-value                  0.992129
# Lags Used               12.000000
# Observations Used       82.000000
# Critical Value (1%)     -3.512738
# Critical Value (5%)     -2.897490
# Critical Value (10%)    -2.585949
# dtype: float64
# Capital
# Test Statistic           2.029053
# p-value                  0.998710
# Lags Used                1.000000
# Observations Used       93.000000
# Critical Value (1%)     -3.502705
# Critical Value (5%)     -2.893158
# Critical Value (10%)    -2.583637
# dtype: float64

# %%
#4 Test VS Train 
size = int(len(df1) * 0.93)
df1_train = df1.iloc[:size]
df1_test = df1.iloc[size:]

# %%
df1_train
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 1922   176904.0     143929.0     12653.0     17821.0        1.61
# 1923   182423.0     148335.0     12990.0     18051.0        1.34
# 1924   191378.0     153246.0     15141.0     18322.0        1.43
# 1925   198406.0     155908.0     17250.0     18532.0        1.68
# 1926   191950.0     156780.0     16743.0     18537.0        1.88
# ...         ...          ...         ...         ...         ...
# 2005  1464210.0    1095514.0    287077.0     28850.0       54.52
# 2006  1500097.0    1113261.0    296121.0     29138.0       65.14
# 2007  1538059.0    1145189.0    312995.0     29378.0       72.39
# 2008  1531690.0    1137565.0    292575.0     29628.0       97.26
# 2009  1463182.0    1100941.0    248099.0     29156.0       61.67
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 1922              7790.0   97.57                     1172.0    1563.0
# 1923              7734.0   94.44                     1048.0    1537.0
# 1924              7676.0   91.05                     1041.0    1519.0
# 1925              7642.0   88.37                     1096.0    1491.0
# 1926              7648.0   92.39                     1155.0    1476.0
# ...                  ...     ...                        ...       ...
# 2005            492200.0  100.46                   534479.0  465844.0
# 2006            527300.0   99.58                   561242.0  510573.0
# 2007            562500.0   98.83                   590694.0  544073.0
# 2008            733300.0   95.51                   643692.0  534237.0
# 2009            938900.0   97.10                   686259.0  574379.0
#
#        Capital
# Year
# 1922   19619.0
# 1923   19684.0
# 1924   19782.0
# 1925   19944.0
# 1926   19977.0
# ...        ...
# 2005  227914.0
# 2006  235660.0
# 2007  245540.0
# 2008  253641.0
# 2009  255568.0
#
# [88 rows x 10 columns]

# %%
df1_test
# Out:
#        Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 2010  1494588.0    1107273.0    260396.0     29228.0       79.50
# 2011  1514583.0    1102262.0    265327.0     29376.0      111.26
# 2012  1530435.0    1121061.0    271534.0     29696.0      111.67
# 2013  1551553.0    1138546.0    280224.0     30044.0      108.66
# 2014  1604169.0    1163136.0    298872.0     30757.0       98.93
# 2015  1642802.0    1190789.0    309144.0     31296.0       52.39
# 2016  1672084.0    1223627.0    310816.0     31741.0       43.82
#
#       Public_Sector_Debt     TOT  Total_Managed_Expenditure        M1  \
# Year
# 2010           1136900.0   98.40                   712512.0  580083.0
# 2011           1240700.0   97.42                   715649.0  578774.0
# 2012           1349700.0   97.81                   735765.0  617849.0
# 2013           1454000.0  100.00                   730662.0  683952.0
# 2014           1556000.0  101.54                   751173.0  734574.0
# 2015           1610500.0  102.27                   752904.0  780106.0
# 2016           1701800.0  102.31                   766473.0  802754.0
#
#        Capital
# Year
# 2010  259292.0
# 2011  263607.0
# 2012  268886.0
# 2013  274195.0
# 2014  280218.0
# 2015  287407.0
# 2016  294233.0

# %%
##5 Data Transformation
# We are going to apply logaritms and then im going to apply differeces to make the variables stacionary

# %%
df1_train_log = np.log(df1_train)

# %%
 fig, axes = plt.subplots(nrows=5, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1_train_log[df1_train_log.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title(df1_train_log.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Now  we appy first doifferences and then we will run ADF test to see if the variables are still stationary

# %%
df1_train_log_diff = (df1_train_log).diff().dropna()

# %%
df1_train_log_diff
# Out:
#       Real_GDP  Consumption  Investment  Employment  Oil_Prices  \
# Year
# 1923  0.030721     0.030153    0.026285    0.012824   -0.183565
# 1924  0.047922     0.032571    0.153226    0.014901    0.065005
# 1925  0.036065     0.017222    0.130406    0.011396    0.161119
# 1926 -0.033081     0.005577   -0.029832    0.000270    0.112478
# 1927  0.078479     0.042416    0.109687    0.028767   -0.368908
# ...        ...          ...         ...         ...         ...
# 2005  0.032020     0.029094    0.034701    0.011154    0.353901
# 2006  0.024214     0.016070    0.031018    0.009933    0.177971
# 2007  0.024991     0.028276    0.055419    0.008203    0.105529
# 2008 -0.004150    -0.006680   -0.067466    0.008474    0.295320
# 2009 -0.045758    -0.032725   -0.164893   -0.016059   -0.455590
#
#       Public_Sector_Debt       TOT  Total_Managed_Expenditure        M1  \
# Year
# 1923           -0.007215 -0.032605                  -0.111828 -0.016775
# 1924           -0.007528 -0.036556                  -0.006702 -0.011780
# 1925           -0.004439 -0.029876                   0.051485 -0.018605
# 1926            0.000785  0.044486                   0.052433 -0.010111
# 1927           -0.001570 -0.004121                  -0.020114  0.012121
# ...                  ...       ...                        ...       ...
# 2005            0.092531 -0.006153                   0.074948  0.121472
# 2006            0.068885 -0.008798                   0.048860  0.091683
# 2007            0.064621 -0.007560                   0.051146  0.063550
# 2008            0.265164 -0.034170                   0.085922 -0.018244
# 2009            0.247154  0.016510                   0.064035  0.072450
#
#        Capital
# Year
# 1923  0.003308
# 1924  0.004966
# 1925  0.008156
# 1926  0.001653
# 1927  0.006486
# ...        ...
# 2005  0.035968
# 2006  0.033422
# 2007  0.041070
# 2008  0.032460
# 2009  0.007569
#
# [87 rows x 10 columns]

# %%
 fig, axes = plt.subplots(nrows=int(len(df1_train_log_diff.columns)/2), ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df1_train_log_diff[df1_train_log_diff.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    #Make charts more readable
    ax.set_title("diff-log-" + df1_train_log_diff.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
# Then i aply dkf test to the transformed variables 

for i in df1_train_log_diff:
    adf_test(df1_train_log_diff[i], i)
# Out:
# Real_GDP
# Test Statistic          -5.350074
# p-value                  0.000004
# Lags Used                1.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# Consumption
# Test Statistic          -5.294196
# p-value                  0.000006
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# Investment
# Test Statistic         -5.955325e+00
# p-value                 2.099916e-07
# Lags Used               1.000000e+00
# Observations Used       8.500000e+01
# Critical Value (1%)    -3.509736e+00
# Critical Value (5%)    -2.896195e+00
# Critical Value (10%)   -2.585258e+00
# dtype: float64
# Employment
# Test Statistic          -4.956223
# p-value                  0.000027
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# Oil_Prices
# Test Statistic         -8.998631e+00
# p-value                 6.589403e-15
# Lags Used               0.000000e+00
# Observations Used       8.600000e+01
# Critical Value (1%)    -3.508783e+00
# Critical Value (5%)    -2.895784e+00
# Critical Value (10%)   -2.585038e+00
# dtype: float64
# Public_Sector_Debt
# Test Statistic          -3.542169
# p-value                  0.006968
# Lags Used                1.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64
# TOT
# Test Statistic         -7.650672e+00
# p-value                 1.792873e-11
# Lags Used               1.000000e+00
# Observations Used       8.500000e+01
# Critical Value (1%)    -3.509736e+00
# Critical Value (5%)    -2.896195e+00
# Critical Value (10%)   -2.585258e+00
# dtype: float64
# Total_Managed_Expenditure
# Test Statistic          -4.738610
# p-value                  0.000071
# Lags Used                5.000000
# Observations Used       81.000000
# Critical Value (1%)     -3.513790
# Critical Value (5%)     -2.897943
# Critical Value (10%)    -2.586191
# dtype: float64
# M1
# Test Statistic          -4.267299
# p-value                  0.000506
# Lags Used                0.000000
# Observations Used       86.000000
# Critical Value (1%)     -3.508783
# Critical Value (5%)     -2.895784
# Critical Value (10%)    -2.585038
# dtype: float64
# Capital
# Test Statistic          -2.285210
# p-value                  0.176783
# Lags Used                1.000000
# Observations Used       85.000000
# Critical Value (1%)     -3.509736
# Critical Value (5%)     -2.896195
# Critical Value (10%)    -2.585258
# dtype: float64

# %%
# all Variables are now stationary, but not the Capital, should we apply second differences to that ?

# %%
### ACF
for i in df1_train_log_diff:
    sgt.plot_acf(df1_train_log_diff[i], lags = 20, zero=False)
    plt.title('ACF for %s' % i) 
    plt.show()

# %%
for i in df1_train_log_diff:
    sgt.plot_pacf(df1_train_log_diff[i], lags = 20, zero=False)
    plt.title('PACF for %s' % i) 
    plt.show()

# %%
##Granger Causality test#
lag=int(((int(len(df1_train.index)))/3)/int(len(df1_train.columns)))
lag
# Out:
# 2

# %% [markdown]
# ### Granjer test

# %%
maxlag=lag

test = 'ssr_chi2test'


def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables) #creating a df with 0 to store granger results
    for c in df.columns:
        for r in df.index:
            test_result = sts.grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)] #This line extracts the p-values from the Granger causality test results. It iterates over each lag from 1 to maxlag (assuming maxlag is defined somewhere), retrieves the p-value from the test results, and rounds it to 4 decimal places.
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
grangers_causation_matrix(df1_train_log_diff, variables = df1_train_log_diff.columns)
# Out:
#                              Real_GDP_x  Consumption_x  Investment_x  \
# Real_GDP_y                       1.0000         0.4509        0.2788
# Consumption_y                    0.1486         1.0000        0.2322
# Investment_y                     0.0028         0.0006        1.0000
# Employment_y                     0.0013         0.6862        0.0128
# Oil_Prices_y                     0.1347         0.0195        0.0243
# Public_Sector_Debt_y             0.3822         0.0976        0.0932
# TOT_y                            0.2818         0.0003        0.0974
# Total_Managed_Expenditure_y      0.0909         0.0848        0.0121
# M1_y                             0.5571         0.0540        0.0055
# Capital_y                        0.0265         0.0030        0.0631
#
#                              Employment_x  Oil_Prices_x  Public_Sector_Debt_x  \
# Real_GDP_y                         0.3392        0.0551                0.1472
# Consumption_y                      0.0081        0.4725                0.1984
# Investment_y                       0.0160        0.1019                0.0156
# Employment_y                       1.0000        0.0535                0.3774
# Oil_Prices_y                       0.6106        1.0000                0.9050
# Public_Sector_Debt_y               0.4724        0.1372                1.0000
# TOT_y                              0.1581        0.0497                0.5530
# Total_Managed_Expenditure_y        0.0028        0.1180                0.1103
# M1_y                               0.3682        0.5122                0.0153
# Capital_y                          0.0015        0.1100                0.0023
#
#                               TOT_x  Total_Managed_Expenditure_x    M1_x  \
# Real_GDP_y                   0.1059                       0.2438  0.0095
# Consumption_y                0.1006                       0.1066  0.0233
# Investment_y                 0.7609                       0.0004  0.5312
# Employment_y                 0.8188                       0.8923  0.0098
# Oil_Prices_y                 0.0519                       0.9096  0.0169
# Public_Sector_Debt_y         0.1683                       0.0050  0.5390
# TOT_y                        1.0000                       0.0622  0.7954
# Total_Managed_Expenditure_y  0.0634                       1.0000  0.4485
# M1_y                         0.3050                       0.0048  1.0000
# Capital_y                    0.8339                       0.0439  0.1319
#
#                              Capital_x
# Real_GDP_y                      0.0935
# Consumption_y                   0.7271
# Investment_y                    0.6908
# Employment_y                    0.1827
# Oil_Prices_y                    0.2717
# Public_Sector_Debt_y            0.3727
# TOT_y                           0.5681
# Total_Managed_Expenditure_y     0.3435
# M1_y                            0.0752
# Capital_y                       1.0000

# %% [markdown]
# ###  VAR model

# %%
 #Initiate VAR model
var_model = VAR(endog=df1_train_log_diff)
res_var = var_model.select_order(maxlags=2, trend='ct')
res_var.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# Based on AIC Criteria we swelect 1 lag fo our model

# %%
 var_model_fit = var_model.fit(maxlags=1, ic='aic')
var_model_fit.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 11, Mar, 2024
# Time:                     10:02:41
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -64.5954
# Nobs:                     86.0000    HQIC:                  -66.4713
# Log likelihood:           1802.30    FPE:                3.88430e-30
# AIC:                     -67.7347    Det(Omega_mle):     1.16568e-30
# --------------------------------------------------------------------
# Results for equation Real_GDP
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.019339         0.007765            2.491           0.013
# L1.Real_GDP                          0.251548         0.165953            1.516           0.130
# L1.Consumption                      -0.180373         0.200931           -0.898           0.369
# L1.Investment                        0.036321         0.028484            1.275           0.202
# L1.Employment                        0.066519         0.264637            0.251           0.802
# L1.Oil_Prices                       -0.019038         0.013067           -1.457           0.145
# L1.Public_Sector_Debt               -0.112991         0.053457           -2.114           0.035
# L1.TOT                               0.090759         0.089186            1.018           0.309
# L1.Total_Managed_Expenditure         0.052812         0.060526            0.873           0.383
# L1.M1                                0.084745         0.053754            1.577           0.115
# L1.Capital                          -0.052033         0.193980           -0.268           0.789
# ===============================================================================================
#
# Results for equation Consumption
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.020367         0.006608            3.082           0.002
# L1.Real_GDP                          0.146692         0.141231            1.039           0.299
# L1.Consumption                      -0.035173         0.170998           -0.206           0.837
# L1.Investment                       -0.033884         0.024241           -1.398           0.162
# L1.Employment                       -0.621899         0.225214           -2.761           0.006
# L1.Oil_Prices                        0.005590         0.011121            0.503           0.615
# L1.Public_Sector_Debt               -0.059070         0.045494           -1.298           0.194
# L1.TOT                               0.099512         0.075900            1.311           0.190
# L1.Total_Managed_Expenditure        -0.164257         0.051509           -3.189           0.001
# L1.M1                                0.192157         0.045746            4.200           0.000
# L1.Capital                           0.232215         0.165082            1.407           0.160
# ===============================================================================================
#
# Results for equation Investment
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0.057489         0.033865            1.698           0.090
# L1.Real_GDP                         -1.075090         0.723764           -1.485           0.137
# L1.Consumption                       1.707046         0.876315            1.948           0.051
# L1.Investment                        0.097032         0.124227            0.781           0.435
# L1.Employment                       -1.450791         1.154152           -1.257           0.209
# L1.Oil_Prices                       -0.081411         0.056990           -1.429           0.153
# L1.Public_Sector_Debt               -0.428626         0.233142           -1.838           0.066
# L1.TOT                              -0.912118         0.388963           -2.345           0.019
# L1.Total_Managed_Expenditure         0.048953         0.263969            0.185           0.853
# L1.M1                                0.149117         0.234436            0.636           0.525
# L1.Capital                          -0.658934         0.845998           -0.779           0.436
# ===============================================================================================
#
# Results for equation Employment
# ===============================================================================================
#                                   coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------
# const                                0
dw_check_var = durbin_watson(var_model_fit.resid)

for col, val in zip(df1_train_log_diff.columns, dw_check_var):
    print("Durbin-Watson statistic for:")
    print(col, '-->', round(val, 2))
    print("----------------------------")
# Out:
# Durbin-Watson statistic for:
# Real_GDP --> 1.88
# ----------------------------
# Durbin-Watson statistic for:
# Consumption --> 2.03
# ----------------------------
# Durbin-Watson statistic for:
# Investment --> 2.0
# ----------------------------
# Durbin-Watson statistic for:
# Employment --> 2.1
# ----------------------------
# Durbin-Watson statistic for:
# Oil_Prices --> 1.85
# ----------------------------
# Durbin-Watson statistic for:
# Public_Sector_Debt --> 1.73
# ----------------------------
# Durbin-Watson statistic for:
# TOT --> 1.95
# ----------------------------
# Durbin-Watson statistic for:
# Total_Managed_Expenditure --> 1.84
# ----------------------------
# Durbin-Watson statistic for:
# M1 --> 2.23
# ----------------------------
# Durbin-Watson statistic for:
# Capital --> 1.92
# ----------------------------

# %%
 #Get the lag order
lag_order = var_model_fit.k_ar
print(lag_order)
# Out:
# 1

# %%
#Input data for forecasting
pred_input = df1_train_log_diff.values[-lag_order:]
pred_input
# Out:
# array([[-0.04575818, -0.03272474, -0.16489318, -0.01605914, -0.45559022,
#          0.24715408,  0.01651042,  0.06403476,  0.0724499 ,  0.00756864]])

# %%
#Forecasting
var_pred = var_model_fit.forecast(y=pred_input, steps=len(df1_test))

df_var_pred = pd.DataFrame(var_pred, index = df1_test.index, columns = df1_train_log_diff.columns + '_1d')

df_var_pred
# Out:
#       Real_GDP_1d  Consumption_1d  Investment_1d  Employment_1d  \
# Year
# 2010    -0.001952        0.020038      -0.016836      -0.013649
# 2011     0.005876        0.047409       0.036976      -0.001994
# 2012     0.004635        0.044348       0.094258       0.001643
# 2013     0.007964        0.035547       0.112291       0.002585
# 2014     0.014382        0.028730       0.098474       0.003885
# 2015     0.019869        0.024410       0.076252       0.005409
# 2016     0.023274        0.021788       0.057531       0.006576
#
#       Oil_Prices_1d  Public_Sector_Debt_1d    TOT_1d  \
# Year
# 2010      -0.206941               0.185036  0.026394
# 2011      -0.101716               0.120899  0.004407
# 2012       0.017723               0.078269 -0.014558
# 2013       0.060750               0.054674 -0.013545
# 2014       0.059539               0.043595 -0.007996
# 2015       0.047444               0.040347 -0.004140
# 2016       0.038106               0.041494 -0.002092
#
#       Total_Managed_Expenditure_1d     M1_1d  Capital_1d
# Year
# 2010                     -0.041730  0.107765    0.003757
# 2011                     -0.082728  0.086019    0.008411
# 2012                     -0.056280  0.072060    0.013596
# 2013                     -0.013114  0.062825    0.016663
# 2014                      0.021606  0.057339    0.018370
# 2015                      0.044810  0.055464    0.019576
# 2016                      0.059459  0.056487    0.020593

# %%
def invert_transformation(df_train, df_forecast):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = np.log(df_train[col].iloc[-1]) + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_var_pred_inv = invert_transformation(df1_train, df_var_pred)
df_var_pred_inv = df_var_pred_inv.filter(regex='_forecast$',axis=1)
df_var_pred_inv = np.exp(df_var_pred_inv) 

round(df_var_pred_inv.head(), 3)
# Out:
#       Real_GDP_forecast  Consumption_forecast  Investment_forecast  \
# Year
# 2010        1460328.306           1123224.221           243956.995
# 2011        1468933.820           1177757.312           253146.316
# 2012        1475758.639           1231163.839           278168.158
# 2013        1487558.055           1275714.696           311225.244
# 2014        1509107.078           1312897.548           343432.523
#
#       Employment_forecast  Oil_Prices_forecast  Public_Sector_Debt_forecast  \
# Year
# 2010            28760.745               50.142                  1129742.041
# 2011            28703.444               45.292                  1274925.781
# 2012            28750.637               46.102                  1378722.468
# 2013            28825.043               48.990                  1456202.184
# 2014            28937.259               51.995                  1521089.327
#
#       TOT_forecast  Total_Managed_Expenditure_forecast  M1_forecast  \
# Year
# 2010        99.697                          658210.982   639735.241
# 2011       100.137                          605949.850   697200.601
# 2012        98.690                          572788.987   749295.465
# 2013        97.362                          565326.671   797879.995
# 2014        96.587                          577674.239   844966.275
#
#       Capital_forecast
# Year
# 2010        256529.852
# 2011        258696.512
# 2012        262237.653
# 2013        266643.936
# 2014        271587.416

# %% [markdown]
#  ### Evaluate the predictions

# %%
 var_mape = metrics.mean_absolute_percentage_error(df1_test, df_var_pred_inv)

var_model_accuracy = 1 - var_mape
print("The accuracy of the VAR out-of-sample prediction is:")
print("----------------------------------------------------")
print(round(var_model_accuracy, 3))
# Out:
# The accuracy of the VAR out-of-sample prediction is:
# ----------------------------------------------------
# 0.885

# %%
fig, axes = plt.subplots(nrows=int(len(df1_test.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df1_test.columns, axes.flatten())):
    df_var_pred_inv[col+'_forecast'].plot(legend=True, ax=ax, linestyle='--').autoscale(axis='x',tight=True)
    df1_test[col].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ### VECM model

# %%
# determine the order of cointegration 
var_model_levels = VAR(endog=df1_train_log)
res_var_levels = var_model_levels.select_order(maxlags=3, trend='ct')
res_var_levels.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# his time, we see that the suggested number of lags by the AIC is 2. Therefore, for both the Johansen cointegration test and for our VECM model, we will use 2–1 lags.

# %%
 def johansen_trace(y, p):
        N, l = y.shape
        joh_trace = coint_johansen(y, 0, p)
        r = 0
        for i in range(l):
            if joh_trace.lr1[i] > joh_trace.cvt[i, 1]:
                r = i + 1
        joh_trace.r = r
        return joh_trace

# %%
 for i in range(1, 2): 
    # tests for cointegration at i lags
    joh_trace = johansen_trace(df1_train_log, i)
    print('Using the Trace Test, there are', joh_trace.r, '''cointegrating vectors at 
    # %s lags between the series''' % i)
    print()
# Out:
# Using the Trace Test, there are 5 cointegrating vectors at
#    1 lags between the series

# %%
j_test = coint_johansen(df1_train_log,0,1)
print ('--------------------------------------------------')
print ('--> Trace Statistics')
print ('variable statistic Crit-90% Crit-95%  Crit-99%')
for i in range(len(j_test.lr1)):
    print ('r =', i, '\t', round(j_test.lr1[i], 4), j_test.cvt[i, 0], j_test.cvt[i, 1], j_test.cvt[i, 2])
print ('--------------------------------------------------')
print ('--> Eigen Statistics')
print ('variable statistic Crit-90% Crit-95%  Crit-99%')
for i in range(len(j_test.lr2)):
    print ('r =', i, '\t', round(j_test.lr2[i], 4), j_test.cvm[i, 0], j_test.cvm[i, 1], j_test.cvm[i, 2])
# Out:
# --------------------------------------------------
# --> Trace Statistics
# variable statistic Crit-90% Crit-95%  Crit-99%
# r = 0 	 371.498 232.103 239.2468 253.2526
# r = 1 	 285.7818 190.8714 197.3772 210.0366
# r = 2 	 206.5613 153.6341 159.529 171.0905
# r = 3 	 148.0225 120.3673 125.6185 135.9825
# r = 4 	 101.4453 91.109 95.7542 104.9637
# r = 5 	 66.7401 65.8202 69.8189 77.8202
# r = 6 	 42.3868 44.4929 47.8545 54.6815
# r = 7 	 22.519 27.0669 29.7961 35.4628
# r = 8 	 9.0979 13.4294 15.4943 19.9349
# r = 9 	 0.0031 2.7055 3.8415 6.6349
# --------------------------------------------------
# --> Eigen Statistics
# variable statistic Crit-90% Crit-95%  Crit-99%
# r = 0 	 85.7161 61.2041 64.504 71.2525
# r = 1 	 79.2205 55.2412 58.4332 64.996
# r = 2 	 58.5388 49.2855 52.3622 58.6634
# r = 3 	 46.5772 43.2947 46.2299 52.3069
# r = 4 	 34.7052 37.2786 40.0763 45.8662
# r = 5 	 24.3533 31.2379 33.8777 39.3693
# r = 6 	 19.8678 25.1236 27.5858 32.7172
# r = 7 	 13.4212 18.8928 21.1314 25.865
# r = 8 	 9.0947 12.2971 14.2639 18.52
# r = 9 	 0.0031 2.7055 3.8415 6.6349

# %%
 vecm_model = VECM(endog = df1_train_log, k_ar_diff = 1, coint_rank = 5, deterministic = 'cili')
vecm_model_fit = vecm_model.fit()

# %%
vecm_model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#     Det. terms outside the coint. relation & lagged endog. parameters for equation Real_GDP
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0.0839      0.141      0.596      0.551      -0.192       0.360
# L1.Consumption                   0.5342      0.139      3.833      0.000       0.261       0.807
# L1.Investment                   -0.0524      0.023     -2.237      0.025      -0.098      -0.006
# L1.Employment                    0.4214      0.189      2.234      0.025       0.052       0.791
# L1.Oil_Prices                   -0.0055      0.009     -0.588      0.557      -0.024       0.013
# L1.Public_Sector_Debt           -0.0506      0.045     -1.135      0.257      -0.138       0.037
# L1.TOT                          -0.0773      0.064     -1.205      0.228      -0.203       0.048
# L1.Total_Managed_Expenditure     0.1792      0.042      4.291      0.000       0.097       0.261
# L1.M1                            0.2075      0.047      4.377      0.000       0.115       0.300
# L1.Capital                      -1.2538      0.363     -3.456      0.001      -1.965      -0.543
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Consumption
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                     -0.2105      0.147     -1.434      0.152      -0.498       0.077
# L1.Consumption                   0.0386      0.145      0.265      0.791      -0.246       0.323
# L1.Investment                    0.0096      0.024      0.393      0.695      -0.038       0.057
# L1.Employment                   -0.0828      0.197     -0.421      0.674      -0.468       0.303
# L1.Oil_Prices                    0.0014      0.010      0.140      0.889      -0.018       0.021
# L1.Public_Sector_Debt           -0.1054      0.047     -2.267      0.023      -0.197      -0.014
# L1.TOT                           0.1032      0.067      1.541      0.123      -0.028       0.234
# L1.Total_Managed_Expenditure    -0.0597      0.044     -1.372      0.170      -0.145       0.026
# L1.M1                            0.1318      0.049      2.667      0.008       0.035       0.229
# L1.Capital                       0.2610      0.378      0.690      0.490      -0.480       1.002
#    Det. terms outside the coint. relation & lagged endog. parameters for equation Investment
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# L1.Real_GDP                      0

# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1     -8.344e-17          0          0      0.000   -8.34e-17   -8.34e-17
# beta.2     -4.945e-17          0          0      0.000   -4.95e-17   -4.95e-17
# beta.3      6.035e-20          0          0      0.000    6.03e-20    6.03e-20
# beta.4         1.0000          0          0      0.000       1.000       1.000
# beta.5     -3.906e-17          0          0      0.000   -3.91e-17   -3.91e-17
# beta.6        -0.2842      0.031     -9.030      0.000      -0.346      -0.222
# beta.7        -0.5083      0.150     -3.384      0.001      -0.803      -0.214
# beta.8         0.1224      0.060      2.056      0.040       0.006       0.239
# beta.9         0.0239      0.560      0.043      0.966      -1.074       1.122
# beta.10       -0.0154      1.198     -0.013      0.990      -2.363       2.332
# const         -5.9109      0.678     -8.724      0.000      -7.239      -4.583
# lin_trend      0.0047      3.234      0.001      0.999      -6.335       6.344
#           Cointegration relations for loading-coefficients-column 5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1     -6.372e-16          0          0      0.000   -6.37e-16   -6.37e-16
# beta.2     -1.368e-16          0          0      0.000   -1.37e-16   -1.37e-16
# beta.3     -6.255e-17          0          0      0.000   -6.26e-17   -6.26e-17
# beta.4      2.848e-16          0          0      0.000    2.85e-16    2.85e-16
# beta.5         1.0000          0          0      0.000       1.000       1.000
# beta.6        -0.7264      1.281     -0.567      0.571      -3.238       1.785
# beta.7         7.8686     12.066      0.652      0.514     -15.779      31.517
# beta.8        -0.9340      0.004   -252.000      0.000      -0.941      -0.927
# beta.9         1.5851      0.002    756.045      0.000       1.581       1.589
# beta.10        1.0256      0.010    102.470      0.000       1.006       1.045
# const        -44.4329      0.004  -1.12e+04      0.000     -44.441     -44.425
# lin_trend     -0.1348      0.037     -3.610      0.000      -0.208      -0.062
# ==============================================================================
# """

# %%
dw_check_vecm = durbin_watson(vecm_model_fit.resid)

for col, val in zip(df1_train_log_diff.columns, dw_check_vecm):
    print("Durbin-Watson statistic for:")
    print(col, '-->', round(val, 2))
    print("----------------------------")
# Out:
# Durbin-Watson statistic for:
# Real_GDP --> 1.98
# ----------------------------
# Durbin-Watson statistic for:
# Consumption --> 2.02
# ----------------------------
# Durbin-Watson statistic for:
# Investment --> 2.03
# ----------------------------
# Durbin-Watson statistic for:
# Employment --> 2.01
# ----------------------------
# Durbin-Watson statistic for:
# Oil_Prices --> 1.9
# ----------------------------
# Durbin-Watson statistic for:
# Public_Sector_Debt --> 2.08
# ----------------------------
# Durbin-Watson statistic for:
# TOT --> 1.95
# ----------------------------
# Durbin-Watson statistic for:
# Total_Managed_Expenditure --> 1.78
# ----------------------------
# Durbin-Watson statistic for:
# M1 --> 2.03
# ----------------------------
# Durbin-Watson statistic for:
# Capital --> 1.73
# ----------------------------

# %%
vecm_pred = vecm_model_fit.predict(steps=len(df1_test))

# %%
df_vecm_pred = pd.DataFrame(vecm_pred, 
                        index=df1_test.index, 
                        columns=df1_train.columns + '_forecast')

# %%
df_vecm_pred_inv = np.exp(df_vecm_pred)  
df_vecm_pred_inv
# Out:
#       Real_GDP_forecast  Consumption_forecast  Investment_forecast  \
# Year
# 2010       1.553858e+06          1.126659e+06        227904.254487
# 2011       1.642556e+06          1.180264e+06        226042.718655
# 2012       1.685281e+06          1.265973e+06        234934.658784
# 2013       1.714329e+06          1.357960e+06        266360.472600
# 2014       1.752932e+06          1.434348e+06        320874.094696
# 2015       1.809766e+06          1.489489e+06        381589.029100
# 2016       1.882884e+06          1.525639e+06        424730.038346
#
#       Employment_forecast  Oil_Prices_forecast  Public_Sector_Debt_forecast  \
# Year
# 2010         29172.964805            48.321076                 1.109329e+06
# 2011         29622.895819            42.901202                 1.188531e+06
# 2012         30190.825109            39.513980                 1.191433e+06
# 2013         30614.174172            39.344748                 1.147162e+06
# 2014         30893.552074            43.608501                 1.086218e+06
# 2015         31103.409544            50.915286                 1.037268e+06
# 2016         31293.675619            59.176650                 1.022404e+06
#
#       TOT_forecast  Total_Managed_Expenditure_forecast   M1_forecast  \
# Year
# 2010     98.303515                       702252.246584  6.424483e+05
# 2011     98.134944                       698627.529894  7.228635e+05
# 2012     99.402214                       678084.483842  8.008322e+05
# 2013     99.968914                       670091.447562  8.825382e+05
# 2014     99.648302                       689884.877019  9.662101e+05
# 2015     99.353980                       743333.850164  1.045160e+06
# 2016     99.295700                       833193.119864  1.115184e+06
#
#       Capital_forecast
# Year
# 2010     260232.474282
# 2011     269811.993585
# 2012     282404.749565
# 2013     296680.383780
# 2014     311883.311237
# 2015     327619.882638
# 2016     343689.542899

# %% [markdown]
# ### Evaluate the predictions

# %%
vecm_mape = metrics.mean_absolute_percentage_error(df1_test, df_vecm_pred_inv)
vecm_model_accuracy = 1 - vecm_mape

print("The accuracy of the VECM out-of-sample prediction is:")
print("----------------------------------------------------")
print(round(vecm_model_accuracy, 3))
# Out:
# The accuracy of the VECM out-of-sample prediction is:
# ----------------------------------------------------
# 0.847

# %%
 fig, axes = plt.subplots(nrows=int(len(df1_test.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df1_test.columns, axes.flatten())):
    df_vecm_pred_inv[col+'_forecast'].plot(legend=True, ax=ax, linestyle="--").autoscale(axis='x',tight=True)
    df1_test[col].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ###  VARMA model

# %%
param_grid = {'p': [1,2,3], 'q':[1,2,3], 'tr': ['n','c','t','ct']}
pg = list(ParameterGrid(param_grid))

# %%
df_fitted_VARMA = pd.DataFrame(columns=['p', 
                                         'q', 
                                         'tr',
                                         'AIC'])

for a,b in enumerate(pg):
    p = b.get('p')
    q = b.get('q')
    tr = b.get('tr')
    model = VARMAX(df1_train_log_diff, order=(p,q), trend=tr, initialization='approximate_diffuse').fit(maxiter=30)
    aic = model.aic
    
    df_fitted_VARMA = df_fitted_VARMA.append({'p': p, 'q': q, 'tr': tr, 'AIC':aic}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2544\3171355360.py in ?()
#       9     tr = b.get('tr')
#      10     model = VARMAX(df1_train_log_diff, order=(p,q), trend=tr, initialization='approximate_diffuse').fit(maxiter=30)
#      11     aic = model.aic
#      12
# ---> 13     df_fitted_VARMA = df_fitted_VARMA.append({'p': p, 'q': q, 'tr': tr, 'AIC':aic}, ignore_index=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
